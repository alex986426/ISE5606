# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from scipy.stats import spearmanr
import statsmodels.api as sm
from statsmodels.formula.api import ols

import warnings
# 忽略所有警告
warnings.filterwarnings("ignore")

# %%
filename = '../002Data/gz_home_data1.csv'
data = pd.read_csv(filename)

# 查看基本信息
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   标题                                                                    5 non-null      object
#  1   地区                                                                    5 non-null      object
#  2   位置                                                                    5 non-null      object
#  3   具体位置                                                                  5 non-null      object
#  4   resblock-tag1_resblock-tag_resblock-type_resblock-tag2_resblock-tag3  5 non-null      object
#  5   均价/平方米每元                                                              5 non-null      object
#  6   总价                                                                    3 non-null      object
#  7   类型                                                                    5 non-null      object
#  8   室厅数                                                                   3 non-null      object
#  9   面积                                                                    3 non-null      object
#  10  Unnamed: 10                                                           0 non-null      float64
# dtypes: float64(1), object(10)
# memory usage: 568.0+ bytes

# %%
# 随机抽取数据，查看具体情况
data.sample(5)
# Out:
#              标题  地区     位置                      具体位置  \
# 2          国化广场  白云  白云大道南        广东省广州市白云区云城北二路116号
# 3       富豪山庄·领峰  番禺   富豪山庄         番禺区东环街市广路232号富豪大厦
# 0         星河湾萝峰  黄埔     香雪  广东省广州市黄埔区萝岗路与启学路交叉口北200米
# 1          时代印记  黄埔    知识城             广东省广州市黄埔区亨美西路
# 4  北大科技园·国际科创广场  白云     石井                   石沙公路81号
#
#   resblock-tag1_resblock-tag_resblock-type_resblock-tag2_resblock-tag3  \
# 2                             商业类,车位充足,人车分流,近地铁,地铁沿线
# 3                               住宅,低单价,低总价,车位充足,低密居所
# 0                             住宅,车位充足,绿化率高,品牌房企,入户花园
# 1                               住宅,低单价,低总价,绿化率高,人车分流
# 4                             商业类,小型社区,近地铁,地铁沿线,综合商场
#
#   均价/平方米每元               总价  类型    室厅数           面积  Unnamed: 10
# 2     价格待定              NaN  待售    NaN          NaN          NaN
# 3    30000   总价159-321(万/套)  在售     1室   建面 53-107㎡          NaN
# 0    38000  总价480-1550(万/套)  在售  3室,5室  建面 130-265㎡          NaN
# 1    18000   总价155-245(万/套)  在售  3室,4室   建面 87-136㎡          NaN
# 4     价格待定              NaN  待售    NaN          NaN          NaN

# %%
# 修改列名
data.rename(columns={'resblock-tag1_resblock-tag_resblock-type_resblock-tag2_resblock-tag3':'标签'},inplace=True)

data = data[['标题','地区','具体位置','类型','均价/平方米每元','室厅数','面积','标签','总价']]

# %%
# 查看各列缺失值
data.isnull().sum()
# Out:
# 标题          0
# 地区          0
# 具体位置        0
# 类型          0
# 均价/平方米每元    0
# 室厅数         2
# 面积          2
# 标签          0
# 总价          2
# dtype: int64

# %%
# 查看数据中的字段大概内容
summary = {
    '标题':[data['标题'].nunique()],
    '类型':list(data['类型'].unique()),
    '具体位置':[data['具体位置'].nunique()],
    '地区':list(data['地区'].unique()),
    '室厅数':list(data['室厅数'].unique()),
}

df = pd.DataFrame.from_dict(summary,orient='index').T
df = df.fillna('')
df

# 删除其中的错误数据，此步骤可以忽略，这是由于作者数据集问题所造成的，在后面才发现，返回来修改
# print(data['类型'].unique())     # ['在售' '待售' '售罄']
index_to_drop = data.loc[data['类型']=='售罄'].index
data = data.drop(index_to_drop)

# %%
# 处理均价字段缺失值,以及异常字段
data['均价/平方米每元'] = data['均价/平方米每元'].replace('价格待定',0)

# 此步骤可以忽视，这是为了删除其中一个特殊的值，防止报错，方法一。
index_drop = data.loc[data['均价/平方米每元']=='112-175'].index
data.drop(data.loc[data['均价/平方米每元']=='800-1600'].index,inplace=True)
data.drop(index_drop,inplace=True)
# 方法二
# data['均价/平方米每元'] = data['均价/平方米每元'].astype(str)
# def delete(datas):
#     if '-' in datas:
#         data.drop(datas,inplace=True)
#     else:
#         pass
# data['均价/平方米每元'] = data['均价/平方米每元'].apply(delete)

# 使用中位数代替数据中的空值
data['均价/平方米每元'] = data['均价/平方米每元'].astype(float)
medians = data['均价/平方米每元'].median()
data['均价/平方米每元'] = data['均价/平方米每元'].replace(0,medians)

# %%
# 处理室厅数字段，由于数据量较少，所以选择填充数据，在这里选择使用众数填充
data['室厅数'].value_counts()
data['室厅数'].fillna('3室,4室',inplace=True)

# 对于不确定的室厅数，计算平均值作为代表
def process_room(room):
    room = room.replace('室','').strip()
    if ',' in room:
        mins, maxs = map(float, room.split(','))
        return int((mins + maxs)/2)
    return int(room)
data['室厅数'] = data['室厅数'].apply(process_room)

data.sample(5)
# Out:
#              标题  地区                      具体位置  类型  均价/平方米每元  室厅数           面积  \
# 0         星河湾萝峰  黄埔  广东省广州市黄埔区萝岗路与启学路交叉口北200米  在售   38000.0    4  建面 130-265㎡
# 1          时代印记  黄埔             广东省广州市黄埔区亨美西路  在售   18000.0    3   建面 87-136㎡
# 3       富豪山庄·领峰  番禺         番禺区东环街市广路232号富豪大厦  在售   30000.0    1   建面 53-107㎡
# 2          国化广场  白云        广东省广州市白云区云城北二路116号  待售   18000.0    3          NaN
# 4  北大科技园·国际科创广场  白云                   石沙公路81号  待售   18000.0    3          NaN
#
#                        标签               总价
# 0  住宅,车位充足,绿化率高,品牌房企,入户花园  总价480-1550(万/套)
# 1    住宅,低单价,低总价,绿化率高,人车分流   总价155-245(万/套)
# 3    住宅,低单价,低总价,车位充足,低密居所   总价159-321(万/套)
# 2  商业类,车位充足,人车分流,近地铁,地铁沿线              NaN
# 4  商业类,小型社区,近地铁,地铁沿线,综合商场              NaN

# %%
# 处理面积字段，并取中位数作为结果
data['面积'] = data['面积'].astype(str)

def process_area(area):
    area = area.replace('建面','').strip()
    area = area.replace('㎡','').strip()
    if "-" in area:
        area_min, area_max = map(float, area.split('-'))
        return (area_min + area_max) / 2
    return float(area)

data['面积'] = data['面积'].apply(process_area)

area_average = int(data['面积'].median())
print(area_average)
data['面积'].fillna(area_average,inplace=True)

data.sample(5)
# Out:
# 111
#              标题  地区                      具体位置  类型  均价/平方米每元  室厅数     面积  \
# 4  北大科技园·国际科创广场  白云                   石沙公路81号  待售   18000.0    3  111.0
# 2          国化广场  白云        广东省广州市白云区云城北二路116号  待售   18000.0    3  111.0
# 0         星河湾萝峰  黄埔  广东省广州市黄埔区萝岗路与启学路交叉口北200米  在售   38000.0    4  197.5
# 1          时代印记  黄埔             广东省广州市黄埔区亨美西路  在售   18000.0    3  111.5
# 3       富豪山庄·领峰  番禺         番禺区东环街市广路232号富豪大厦  在售   30000.0    1   80.0
#
#                        标签               总价
# 4  商业类,小型社区,近地铁,地铁沿线,综合商场              NaN
# 2  商业类,车位充足,人车分流,近地铁,地铁沿线              NaN
# 0  住宅,车位充足,绿化率高,品牌房企,入户花园  总价480-1550(万/套)
# 1    住宅,低单价,低总价,绿化率高,人车分流   总价155-245(万/套)
# 3    住宅,低单价,低总价,车位充足,低密居所   总价159-321(万/套)

# %%
# 处理总价字段，使用中位数作为最后的总价数
data['总价'] = data['总价'].astype(str)

def process_total(total):
    total = total.replace('总价','').strip()
    total = total.replace("(万/套)",'').strip()
    if '-' in total:
        total_min, total_max = map(float, total.split('-'))
        return (total_min + total_max) / 2
    return float(total)

data['总价'] = data['总价'].apply(process_total)

# 使用中位数填充总价字段的缺失值
total_median = data['总价'].median()
print(total_median)
data['总价'].fillna(total_median,inplace=True)

data.sample(5)
# Out:
# 240.0
#              标题  地区                      具体位置  类型  均价/平方米每元  室厅数     面积  \
# 3       富豪山庄·领峰  番禺         番禺区东环街市广路232号富豪大厦  在售   30000.0    1   80.0
# 2          国化广场  白云        广东省广州市白云区云城北二路116号  待售   18000.0    3  111.0
# 4  北大科技园·国际科创广场  白云                   石沙公路81号  待售   18000.0    3  111.0
# 1          时代印记  黄埔             广东省广州市黄埔区亨美西路  在售   18000.0    3  111.5
# 0         星河湾萝峰  黄埔  广东省广州市黄埔区萝岗路与启学路交叉口北200米  在售   38000.0    4  197.5
#
#                        标签      总价
# 3    住宅,低单价,低总价,车位充足,低密居所   240.0
# 2  商业类,车位充足,人车分流,近地铁,地铁沿线   240.0
# 4  商业类,小型社区,近地铁,地铁沿线,综合商场   240.0
# 1    住宅,低单价,低总价,绿化率高,人车分流   200.0
# 0  住宅,车位充足,绿化率高,品牌房企,入户花园  1015.0

# %%
data.describe()
# Out:
#            均价/平方米每元       室厅数          面积           总价
# count      5.000000  5.000000    5.000000     5.000000
# mean   24400.000000  2.800000  122.200000   387.000000
# std     9208.691547  1.095445   44.204921   351.489687
# min    18000.000000  1.000000   80.000000   200.000000
# 25%    18000.000000  3.000000  111.000000   240.000000
# 50%    18000.000000  3.000000  111.000000   240.000000
# 75%    30000.000000  3.000000  111.500000   240.000000
# max    38000.000000  4.000000  197.500000  1015.000000

# %%
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.hist(data['均价/平方米每元'])
plt.title('均价分布')

plt.subplot(2,2,2)
plt.hist(data['室厅数'])
plt.title('室厅数分布')

plt.subplot(2,2,3)
plt.hist(data['面积'])
plt.title('面积分布')

plt.subplot(2,2,4)
plt.hist(data['总价'])
plt.title('总价分布')

plt.show()

# %%
# 计算各地区的小区数量，并按降序排列
region_order = data['地区'].value_counts().index
# print(region_order)

# 计算各行政区的平均单价，按新的顺序对平均单价排序
average_price1 = data.groupby('地区')['均价/平方米每元'].mean()
average_price1 = average_price1.reindex(region_order)
# print(average_price1)

# 计算总体平均单价
overall_average_price = data['均价/平方米每元'].mean()

fig, ax1 = plt.subplots(figsize=(12, 6))

# 按降序排列绘制小区数量的柱状图
sns.countplot(data=data, x='地区', order=region_order, ax=ax1, color='c')
ax1.set_xlabel('地区')
ax1.set_ylabel('小区数量')
ax1.tick_params(axis='x')

# 创建第二个坐标轴，用于绘制各个行政区的单价折线图
ax2 = ax1.twinx()
ax2.plot(average_price1.index, average_price1.values, color='b', marker='o', linestyle='-',label='各区平均单价')
ax2.set_ylabel('平均单价（元/平米）')

# 标出总体平均单价
ax2.axhline(overall_average_price, color='r', linestyle='--', label=f'总体平均单价: {overall_average_price:.2f} 元/平米')
ax2.legend(loc='upper right')

plt.title('不同行政区的楼盘数量和平均单价')
plt.show()

# %%
# 提取小区标签并统计出现次数
tags = data['标签'].str.split(',').explode()
tag_counts = Counter(tags)
print(tag_counts)
# Out:
# Counter({'住宅': 3, '车位充足': 3, '绿化率高': 2, '低单价': 2, '低总价': 2, '人车分流': 2, '商业类': 2, '近地铁': 2, '地铁沿线': 2, '品牌房企': 1, '入户花园': 1, '低密居所': 1, '小型社区': 1, '综合商场': 1})

# %%
# 提取小区标签并统计出现次数
tags = data['标签'].str.split(',').explode()
tag_counts = Counter(tags)
print(tag_counts)

# 生成词云图,在本地运行时候font_path替换成本地字体

wordcloud = WordCloud(font_path="test.ttf",background_color='white', width=800, height=400).generate_from_frequencies(tag_counts)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('小区标签词云图')
plt.show()
# Out:
# Counter({'住宅': 3, '车位充足': 3, '绿化率高': 2, '低单价': 2, '低总价': 2, '人车分流': 2, '商业类': 2, '近地铁': 2, '地铁沿线': 2, '品牌房企': 1, '入户花园': 1, '低密居所': 1, '小型社区': 1, '综合商场': 1})

# %%
# 通过以上的描述分析可知【均价，总价，面积】呈现偏态分布
# 进行对数变换
data['对数均价/平方米每元'] = np.log(data['均价/平方米每元'])
data['对数总价'] = np.log(data['总价'])
data['对数面积'] = np.log(data['面积'])

plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.hist(data['对数均价/平方米每元'])
plt.title('均价分布')

plt.subplot(2,2,2)
plt.hist(data['室厅数'])
plt.title('室厅数分布')

plt.subplot(2,2,3)
plt.hist(data['对数面积'])
plt.title('面积分布')

plt.subplot(2,2,4)
plt.hist(data['对数总价'])
plt.title('总价分布')

plt.show()

# %%
df = data.copy()

# 2. 查看标签字段的分布
标签_series = df['标签'].str.split(',')  # 如果每行只有一个标签，可以忽略这一步
标签_counts = Counter(tag.strip() for tags in 标签_series for tag in tags)
标签_counts = pd.Series(标签_counts).sort_values(ascending=False)

# 3. 筛选出现次数大于200的标签
频繁标签 = 标签_counts[标签_counts > 0].index.tolist()
print("频繁标签:", 频繁标签)

# 4. 创建新的二进制字段
df['标签列表'] = df['标签'].str.split(',')
df['标签列表'] = df['标签列表'].apply(lambda tags: [tag.strip() for tag in tags])

for 标签 in 频繁标签:
    df[f'是否是{标签}'] = df['标签列表'].apply(lambda tags: 1 if 标签 in tags else 0)

# 5. 删除临时列
df = df.drop(columns=['标签列表'])

df.sample()
# Out:
# 频繁标签: ['住宅', '车位充足', '绿化率高', '低单价', '低总价', '人车分流', '商业类', '近地铁', '地铁沿线', '品牌房企', '入户花园', '低密居所', '小型社区', '综合商场']
#       标题  地区                      具体位置  类型  均价/平方米每元  室厅数     面积  \
# 0  星河湾萝峰  黄埔  广东省广州市黄埔区萝岗路与启学路交叉口北200米  在售   38000.0    4  197.5
#
#                        标签      总价  对数均价/平方米每元  ...  是否是低总价  是否是人车分流  是否是商业类  \
# 0  住宅,车位充足,绿化率高,品牌房企,入户花园  1015.0   10.545341  ...       0        0       0
#
#    是否是近地铁  是否是地铁沿线  是否是品牌房企  是否是入户花园  是否是低密居所  是否是小型社区  是否是综合商场
# 0       0        0        1        1        0        0        0
#
# [1 rows x 26 columns]

# %%
df.sample()
# Out:
#      标题  地区           具体位置  类型  均价/平方米每元  室厅数     面积                    标签  \
# 1  时代印记  黄埔  广东省广州市黄埔区亨美西路  在售   18000.0    3  111.5  住宅,低单价,低总价,绿化率高,人车分流
#
#       总价  对数均价/平方米每元  ...  是否是低总价  是否是人车分流  是否是商业类  是否是近地铁  是否是地铁沿线  是否是品牌房企  \
# 1  200.0    9.798127  ...       1        1       0       0        0        0
#
#    是否是入户花园  是否是低密居所  是否是小型社区  是否是综合商场
# 1        0        0        0        0
#
# [1 rows x 26 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib import font_manager

# 设置中文字体
font_path = 'test.ttf'  # 替换为你的字体文件路径
font_prop = font_manager.FontProperties(fname=font_path)
#plt.rcParams['font.sans-serif'] = font_prop.get_name()
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

new_df = df[['总价','均价/平方米每元','面积','室厅数']]

corr_df = new_df.corr(method='spearman')

# 设置热力图的尺寸
plt.figure(figsize=(6, 4))

# 使用seaborn的heatmap绘制相关性矩阵
sns.heatmap(corr_df, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, 
            xticklabels=corr_df.columns, yticklabels=corr_df.columns)

# 设置标题
plt.title("变量间的相关性热力图", fontproperties=font_prop)
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.show()

# %%
print(df['对数均价/平方米每元'])
# Out:
# 0    10.545341
# 1     9.798127
# 2     9.798127
# 3    10.308953
# 4     9.798127
# Name: 对数均价/平方米每元, dtype: float64

# %%
from scipy.stats import chi2_contingency

class_data = ['是否是品牌房企', '是否是住宅', '是否是人车分流', '是否是车位充足', '是否是绿化率高', 
                '是否是小型社区', '是否是低总价', '是否是近地铁', '是否是地铁沿线', '是否是商业类','是否是低单价']

for i in class_data:
    contingency_table = pd.crosstab(df[i], df['对数均价/平方米每元'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    #if p < 0.05:
    print(f"{i}p值: {p}")
# Out:
# 是否是品牌房企p值: 0.08208499862389874
# 是否是住宅p值: 0.32919298780790557
# 是否是人车分流p值: 0.32919298780790557
# 是否是车位充足p值: 0.32919298780790557
# 是否是绿化率高p值: 0.3291929878079055
# 是否是小型社区p值: 0.6592406302004438
# 是否是低总价p值: 0.3291929878079055
# 是否是近地铁p值: 0.32919298780790557
# 是否是地铁沿线p值: 0.32919298780790557
# 是否是商业类p值: 0.32919298780790557
# 是否是低单价p值: 0.3291929878079055

# %%
class_data = ['是否是品牌房企', '是否是住宅', '是否是人车分流', '是否是车位充足',  '是否是绿化率高', 
                '是否是小型社区', '是否是低总价', '是否是近地铁', '是否是地铁沿线', '是否是商业类','是否是低单价']

for i in class_data:
    contingency_table = pd.crosstab(df[i], df['对数总价'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    #if p < 0.05:
    print(f"{i}p值: {p}")
# Out:
# 是否是品牌房企p值: 0.08208499862389874
# 是否是住宅p值: 0.32919298780790557
# 是否是人车分流p值: 0.3291929878079056
# 是否是车位充足p值: 0.3291929878079056
# 是否是绿化率高p值: 0.0820849986238988
# 是否是小型社区p值: 0.6592406302004438
# 是否是低总价p值: 0.3291929878079056
# 是否是近地铁p值: 0.32919298780790557
# 是否是地铁沿线p值: 0.32919298780790557
# 是否是商业类p值: 0.32919298780790557
# 是否是低单价p值: 0.3291929878079056

# %%
#05、建立模型—线性回归模型
data = df.copy()
data.sample()
# Out:
#         标题  地区               具体位置  类型  均价/平方米每元  室厅数    面积  \
# 3  富豪山庄·领峰  番禺  番禺区东环街市广路232号富豪大厦  在售   30000.0    1  80.0
#
#                      标签     总价  对数均价/平方米每元  ...  是否是低总价  是否是人车分流  是否是商业类  \
# 3  住宅,低单价,低总价,车位充足,低密居所  240.0   10.308953  ...       1        0       0
#
#    是否是近地铁  是否是地铁沿线  是否是品牌房企  是否是入户花园  是否是低密居所  是否是小型社区  是否是综合商场
# 3       0        0        0        0        1        0        0
#
# [1 rows x 26 columns]

# %%
# 首先分析总价
# 设置自变量与因变量
X = data[['对数均价/平方米每元','对数面积','室厅数','是否是住宅','是否是车位充足','是否是绿化率高','是否是低总价','是否是低单价']]
y = data['对数总价']
X = sm.add_constant(X)

model = sm.OLS(y,X)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   对数总价   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Fri, 07 Mar 2025   Prob (F-statistic):                nan
# Time:                        20:23:21   Log-Likelihood:                 159.20
# No. Observations:                   5   AIC:                            -308.4
# Df Residuals:                       0   BIC:                            -310.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0929        inf         -0        nan         nan         nan
# 对数均价/平方米每元     0.5072        inf          0        nan         nan         nan
# 对数面积           0.1892        inf          0        nan         nan         nan
# 室厅数           -0.0957        inf         -0        nan         nan         nan
# 是否是住宅          0.8443        inf          0        nan         nan         nan
# 是否是车位充足    -8.882e-16        inf         -0        nan         nan         nan
# 是否是绿化率高        0.2055        inf          0        nan         nan         nan
# 是否是低总价        -0.6165        inf         -0        nan         nan         nan
# 是否是低单价        -0.6165        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.037
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.052
# Skew:                           0.000   Prob(JB):                        0.974
# Kurtosis:                       2.500   Cond. No.                         71.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.

# %%
# 分析均价
# 设置自变量与因变量
X = data[['对数总价','对数面积','室厅数','是否是品牌房企', '是否是住宅', '是否是人车分流', '是否是车位充足', 
            '是否是绿化率高', '是否是小型社区', '是否是低总价', '是否是近地铁', '是否是地铁沿线','是否是低单价']]
y = data['对数均价/平方米每元']
X = sm.add_constant(X)

model = sm.OLS(y,X)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             对数均价/平方米每元   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Fri, 07 Mar 2025   Prob (F-statistic):                nan
# Time:                        20:23:21   Log-Likelihood:                 160.99
# No. Observations:                   5   AIC:                            -312.0
# Df Residuals:                       0   BIC:                            -313.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2601        inf          0        nan         nan         nan
# 对数总价           0.9591        inf          0        nan         nan         nan
# 对数面积           0.9325        inf          0        nan         nan         nan
# 室厅数           -0.2094        inf         -0        nan         nan         nan
# 是否是品牌房企       -0.3164        inf         -0        nan         nan         nan
# 是否是住宅          0.0752        inf          0        nan         nan         nan
# 是否是人车分流        0.0915        inf          0        nan         nan         nan
# 是否是车位充足        0.0568        inf          0        nan         nan         nan
# 是否是绿化率高       -0.2614        inf         -0        nan         nan         nan
# 是否是小型社区        0.1483        inf          0        nan         nan         nan
# 是否是低总价         0.3916        inf          0        nan         nan         nan
# 是否是近地铁         0.1848        inf          0        nan         nan         nan
# 是否是地铁沿线        0.1848        inf          0        nan         nan         nan
# 是否是低单价         0.3916        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.000
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.690
# Skew:                          -0.212   Prob(JB):                        0.708
# Kurtosis:                       1.230   Cond. No.                         15.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.metrics import MeanSquaredError

# %%
# 2. 数据预处理
X = data[['对数均价/平方米每元','对数面积','室厅数','是否是住宅','是否是车位充足','是否是绿化率高','是否是低总价','是否是低单价']].values
y = data['对数总价'].values
# 特征缩放
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 3. 构建人工神经网络
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)  # 输出层
])

model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])

# 4. 训练模型
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# # 5. 测试模型
# test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
# print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# 5. 评估模型并计算 R²
y_pred = model.predict(X_test).flatten()

# R² 计算
ss_res = np.sum((y_test - y_pred) ** 2)
ss_tot = np.sum((y_test - np.mean(y_test)) ** 2)
r2_score = 1 - (ss_res / ss_tot)

print(f"R²: {r2_score:.4f}")

# 6. 使用模型进行预测
predictions = model.predict(X_test[:9])
print(f"真实值: {y_test[:9]}")
print(f"预测值: {predictions.flatten()}")
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - loss: 34.2693 - mean_squared_error: 34.2693 - val_loss: 26.0337 - val_mean_squared_error: 26.0337
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 33.9572 - mean_squared_error: 33.9572 - val_loss: 25.7564 - val_mean_squared_error: 25.7564
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 33.6527 - mean_squared_error: 33.6527 - val_loss: 25.4819 - val_mean_squared_error: 25.4819
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 33.3499 - mean_squared_error: 33.3499 - val_loss: 25.2056 - val_mean_squared_error: 25.2056
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 33.0348 - mean_squared_error: 33.0348 - val_loss: 24.9118 - val_mean_squared_error: 24.9118
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 32.7094 - mean_squared_error: 32.7094 - val_loss: 24.6079 - val_mean_squared_error: 24.6079
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 32.3702 - mean_squared_error: 32.3702 - val_loss: 24.3066 - val_mean_squared_error: 24.3066
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 32.0260 - mean_squared_error: 32.0260 - val_loss: 24.0075 - val_mean_squared_error: 24.0075
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 31.6833 - mean_squared_error: 31.6833 - val_loss: 23.7113 - val_mean_squared_error: 23.7113
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 31.3370 - mean_squared_error: 31.3370 - val_loss: 23.4172 - val_mean_squared_error: 23.4172
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 30.9912 - mean_squared_error: 30.9912 - val_loss: 23.1289 - val_mean_squared_error: 23.1289
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 30.6444 - mean_squared_error: 30.6444 - val_loss: 22.8454 - val_mean_squared_error: 22.8454
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 30.2942 - mean_squared_error: 30.2942 - val_loss: 22.5632 - val_mean_squared_error: 22.5632
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 29.9400 - mean_squared_error: 29.9400 - val_loss: 22.2823 - val_mean_squared_error: 22.2823
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 29.5840 - mean_squared_error: 29.5840 - val_loss: 22.0044 - val_mean_squared_error: 22.0044
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 29.2256 - mean_squared_error: 29.2256 - val_loss: 21.7279 - val_mean_squared_error: 21.7279
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 28.8649 - mean_squared_error: 28.8649 - val_loss: 21.4521 - val_mean_squared_error: 21.4521
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 28.5020 - mean_squared_error: 28.5020 - val_loss: 21.1768 - val_mean_squared_error: 21.1768
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 28.1369 - mean_squared_error: 28.1369 - val_loss: 20.9019 - val_mean_squared_error: 20.9019
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27.7691 - mean_squared_error: 27.7691 - val_loss: 20.6246 - val_mean_squared_error: 20.6246
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27.3969 - mean_squared_error: 27.3969 - val_loss: 20.3372 - val_mean_squared_error: 20.3372
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27.0223 - mean_squared_error: 27.0223 - val_loss: 20.0498 - val_mean_squared_error: 20.0498
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 26.6454 - mean_squared_error: 26.6454 - val_loss: 19.7625 - val_mean_squared_error: 19.7625
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26.2663 - mean_squared_error: 26.2663 - val_loss: 19.4751 - val_mean_squared_error: 19.4751
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25.8856 - mean_squared_error: 25.8856 - val_loss: 19.1877 - val_mean_squared_error: 19.1877
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 25.5119 - mean_squared_error: 25.5119 - val_loss: 18.8818 - val_mean_squared_error: 18.8818
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25.1371 - mean_squared_error: 25.1371 - val_loss: 18.5758 - val_mean_squared_error: 18.5758
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 24.7524 - mean_squared_error: 24.7524 - val_loss: 18.2710 - val_mean_squared_error: 18.2710
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 24.3617 - mean_squared_error: 24.3617 - val_loss: 17.9659 - val_mean_squared_error: 17.9659
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 23.9668 - mean_squared_error: 23.9668 - val_loss: 17.6604 - val_mean_squared_error: 17.6604
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 23.5692 - mean_squared_error: 23.5692 - val_loss: 17.3545 - val_mean_squared_error: 17.3545
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 23.1688 - mean_squared_error: 23.1688 - val_loss: 17.0485 - val_mean_squared_error: 17.0485
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 22.7668 - mean_squared_error: 22.7668 - val_loss: 16.7425 - val_mean_squared_error: 16.7425
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22.3646 - mean_squared_error: 22.3646 - val_loss: 16.4366 - val_mean_squared_error: 16.4366
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 21.9584 - mean_squared_error: 21.9584 - val_loss: 16.1309 - val_mean_squared_error: 16.1309
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21.5501 - mean_squared_error: 21.5501 - val_loss: 15.8254 - val_mean_squared_error: 15.8254
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 21.1400 - mean_squared_error: 21.1400 - val_loss: 15.5202 - val_mean_squared_error: 15.5202
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 20.7272 - mean_squared_error: 20.7272 - val_loss: 15.2047 - val_mean_squared_error: 15.2047
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20.3099 - mean_squared_error: 20.3099 - val_loss: 14.8860 - val_mean_squared_error: 14.8860
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 19.8934 - mean_squared_error: 19.8934 - val_loss: 14.5652 - val_mean_squared_error: 14.5652
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 19.4751 - mean_squared_error: 19.4751 - val_loss: 14.2431 - val_mean_squared_error: 14.2431
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 19.0555 - mean_squared_error: 19.0555 - val_loss: 13.9202 - val_mean_squared_error: 13.9202
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 18.6342 - mean_squared_error: 18.6342 - val_loss: 13.5968 - val_mean_squared_error: 13.5968
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 18.2127 - mean_squared_error: 18.2127 - val_loss: 13.2733 - val_mean_squared_error: 13.2733
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 17.7922 - mean_squared_error: 17.7922 - val_loss: 12.9461 - val_mean_squared_error: 12.9461
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 17.3764 - mean_squared_error: 17.3764 - val_loss: 12.5982 - val_mean_squared_error: 12.5982
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 16.9668 - mean_squared_error: 16.9668 - val_loss: 12.2522 - val_mean_squared_error: 12.2522
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 16.5576 - mean_squared_error: 16.5576 - val_loss: 11.9084 - val_mean_squared_error: 11.9084
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 16.1489 - mean_squared_error: 16.1489 - val_loss: 11.5653 - val_mean_squared_error: 11.5653
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 15.7333 - mean_squared_error: 15.7333 - val_loss: 11.2182 - val_mean_squared_error: 11.2182
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 15.3135 - mean_squared_error: 15.3135 - val_loss: 10.8727 - val_mean_squared_error: 10.8727
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14.8943 - mean_squared_error: 14.8943 - val_loss: 10.5290 - val_mean_squared_error: 10.5290
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 14.4730 - mean_squared_error: 14.4730 - val_loss: 10.1841 - val_mean_squared_error: 10.1841
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 14.0476 - mean_squared_error: 14.0476 - val_loss: 9.8391 - val_mean_squared_error: 9.8391
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 13.6158 - mean_squared_error: 13.6158 - val_loss: 9.4973 - val_mean_squared_error: 9.4973
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 13.1865 - mean_squared_error: 13.1865 - val_loss: 9.1631 - val_mean_squared_error: 9.1631
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 12.7598 - mean_squared_error: 12.7598 - val_loss: 8.8329 - val_mean_squared_error: 8.8329
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12.3364 - mean_squared_error: 12.3364 - val_loss: 8.5066 - val_mean_squared_error: 8.5066
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 11.9201 - mean_squared_error: 11.9201 - val_loss: 8.1847 - val_mean_squared_error: 8.1847
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 11.5086 - mean_squared_error: 11.5086 - val_loss: 7.8674 - val_mean_squared_error: 7.8674
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 11.1015 - mean_squared_error: 11.1015 - val_loss: 7.5531 - val_mean_squared_error: 7.5531
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 10.6955 - mean_squared_error: 10.6955 - val_loss: 7.2459 - val_mean_squared_error: 7.2459
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 10.2927 - mean_squared_error: 10.2927 - val_loss: 6.9488 - val_mean_squared_error: 6.9488
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.8975 - mean_squared_error: 9.8975 - val_loss: 6.6570 - val_mean_squared_error: 6.6570
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 9.5102 - mean_squared_error: 9.5102 - val_loss: 6.3705 - val_mean_squared_error: 6.3705
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 9.1287 - mean_squared_error: 9.1287 - val_loss: 6.0899 - val_mean_squared_error: 6.0899
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.7562 - mean_squared_error: 8.7562 - val_loss: 5.8155 - val_mean_squared_error: 5.8155
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.3939 - mean_squared_error: 8.3939 - val_loss: 5.5476 - val_mean_squared_error: 5.5476
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.0428 - mean_squared_error: 8.0428 - val_loss: 5.2865 - val_mean_squared_error: 5.2865
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.7034 - mean_squared_error: 7.7034 - val_loss: 5.0326 - val_mean_squared_error: 5.0326
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.3764 - mean_squared_error: 7.3764 - val_loss: 4.7861 - val_mean_squared_error: 4.7861
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.0625 - mean_squared_error: 7.0625 - val_loss: 4.5474 - val_mean_squared_error: 4.5474
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.7620 - mean_squared_error: 6.7620 - val_loss: 4.3167 - val_mean_squared_error: 4.3167
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.4778 - mean_squared_error: 6.4778 - val_loss: 4.0941 - val_mean_squared_error: 4.0941
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.2076 - mean_squared_error: 6.2076 - val_loss: 3.8800 - val_mean_squared_error: 3.8800
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.9514 - mean_squared_error: 5.9514 - val_loss: 3.6745 - val_mean_squared_error: 3.6745
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.7093 - mean_squared_error: 5.7093 - val_loss: 3.4658 - val_mean_squared_error: 3.4658
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.4806 - mean_squared_error: 5.4806 - val_loss: 3.2628 - val_mean_squared_error: 3.2628
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.2622 - mean_squared_error: 5.2622 - val_loss: 3.0699 - val_mean_squared_error: 3.0699
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.0573 - mean_squared_error: 5.0573 - val_loss: 2.8870 - val_mean_squared_error: 2.8870
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.8642 - mean_squared_error: 4.8642 - val_loss: 2.7141 - val_mean_squared_error: 2.7141
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.6836 - mean_squared_error: 4.6836 - val_loss: 2.5511 - val_mean_squared_error: 2.5511
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.5155 - mean_squared_error: 4.5155 - val_loss: 2.3978 - val_mean_squared_error: 2.3978
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.3597 - mean_squared_error: 4.3597 - val_loss: 2.2544 - val_mean_squared_error: 2.2544
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.2156 - mean_squared_error: 4.2156 - val_loss: 2.1205 - val_mean_squared_error: 2.1205
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.0825 - mean_squared_error: 4.0825 - val_loss: 1.9961 - val_mean_squared_error: 1.9961
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.9601 - mean_squared_error: 3.9601 - val_loss: 1.8808 - val_mean_squared_error: 1.8808
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.8481 - mean_squared_error: 3.8481 - val_loss: 1.7746 - val_mean_squared_error: 1.7746
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.7449 - mean_squared_error: 3.7449 - val_loss: 1.6771 - val_mean_squared_error: 1.6771
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.6495 - mean_squared_error: 3.6495 - val_loss: 1.5879 - val_mean_squared_error: 1.5879
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.5612 - mean_squared_error: 3.5612 - val_loss: 1.5068 - val_mean_squared_error: 1.5068
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4791 - mean_squared_error: 3.4791 - val_loss: 1.4335 - val_mean_squared_error: 1.4335
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.4025 - mean_squared_error: 3.4025 - val_loss: 1.3674 - val_mean_squared_error: 1.3674
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.3305 - mean_squared_error: 3.3305 - val_loss: 1.3084 - val_mean_squared_error: 1.3084
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.2623 - mean_squared_error: 3.2623 - val_loss: 1.2559 - val_mean_squared_error: 1.2559
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.1977 - mean_squared_error: 3.1977 - val_loss: 1.2095 - val_mean_squared_error: 1.2095
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.1364 - mean_squared_error: 3.1364 - val_loss: 1.1691 - val_mean_squared_error: 1.1691
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.0760 - mean_squared_error: 3.0760 - val_loss: 1.1341 - val_mean_squared_error: 1.1341
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.0173 - mean_squared_error: 3.0173 - val_loss: 1.1042 - val_mean_squared_error: 1.1042
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.9599 - mean_squared_error: 2.9599 - val_loss: 1.0791 - val_mean_squared_error: 1.0791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# R²: -inf
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 真实值: [5.29831737]
# 预测值: [4.920828]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error,accuracy_score

# %%
# 设定自变量与因变量，并划分训练集与测试集
# 首先分析总价
X = data[['对数均价/平方米每元','对数面积','室厅数','是否是住宅','是否是车位充足','是否是绿化率高','是否是低总价','是否是低单价']]
Y = data['对数总价']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# 训练模型
models = RandomForestRegressor(n_estimators=50,random_state=42)
models.fit(X_train,Y_train)

# 预测测试集结果
y_pred = models.predict(X_test)

# 计算准确率
mae = mean_absolute_error(Y_test,y_pred)
mse = mean_squared_error(Y_test,y_pred)
r2 = r2_score(Y_test,y_pred)

print('mae:',mae)
print('mse:',mse)
print('r2:',r2)
# Out:
# mae: 0.3795617720237545
# mse: 0.1756377037226854
# r2: -20.134973169515995

# %%
# 设定自变量与因变量，并划分训练集与测试集
# 分析均价
X = data[['对数总价','对数面积','室厅数','是否是品牌房企','是否是住宅','是否是人车分流','是否是车位充足',
            '是否是绿化率高','是否是小型社区','是否是低总价','是否是近地铁','是否是地铁沿线','是否是低单价']]
y = data['对数均价/平方米每元']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# 训练模型
models = RandomForestRegressor(n_estimators=50,random_state=42)
models.fit(X_train,Y_train)

# 预测测试集结果
y_pred = models.predict(X_test)

# 计算准确率
mae = mean_absolute_error(Y_test,y_pred)
mse = mean_squared_error(Y_test,y_pred)
r2 = r2_score(Y_test,y_pred)

print('mae:',mae)
print('mse:',mse)
print('r2:',r2)
# Out:
# mae: 0.39398182170509344
# mse: 0.16636898709176712
# r2: -19.01964272987644
