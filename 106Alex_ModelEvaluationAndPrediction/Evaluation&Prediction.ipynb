# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from scipy.stats import spearmanr
import statsmodels.api as sm
from statsmodels.formula.api import ols

import warnings
# 忽略所有警告
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.metrics import MeanSquaredError

# %%
filename = '../002Data/preprocessing data.csv'
data = pd.read_csv(filename, encoding='utf-8')
data['室厅数'] = data['室厅数'].str.replace('室', '')

# %%
# 2. 数据预处理
X = data[['对数均价/平方米每元','对数面积','室厅数','是否是车位充足','是否是绿化率高','是否是低总价','是否是低单价']].values
y = data['对数总价'].values
# 特征缩放
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 3. 构建人工神经网络
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)  # 输出层
])

model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])

# 4. 训练模型
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# # 5. 测试模型
# test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
# print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# 5. 评估模型并计算 R²
y_pred = model.predict(X_test).flatten()

# R² 计算
ss_res = np.sum((y_test - y_pred) ** 2)
ss_tot = np.sum((y_test - np.mean(y_test)) ** 2)
r2_score = 1 - (ss_res / ss_tot)

print(f"R²: {r2_score:.4f}")

# 6. 使用模型进行预测
predictions = model.predict(X_test[:9])
print(f"真实值: {y_test[:9]}")
print(f"预测值: {predictions.flatten()}")
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.0701 - mean_squared_error: 31.0701 - val_loss: 27.5536 - val_mean_squared_error: 27.5536
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.0306 - mean_squared_error: 26.0306 - val_loss: 23.0892 - val_mean_squared_error: 23.0892
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.0776 - mean_squared_error: 22.0776 - val_loss: 18.3698 - val_mean_squared_error: 18.3698
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.2830 - mean_squared_error: 17.2830 - val_loss: 13.2221 - val_mean_squared_error: 13.2221
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.7618 - mean_squared_error: 11.7618 - val_loss: 7.9600 - val_mean_squared_error: 7.9600
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0313 - mean_squared_error: 7.0313 - val_loss: 3.6592 - val_mean_squared_error: 3.6592
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2218 - mean_squared_error: 3.2218 - val_loss: 1.6583 - val_mean_squared_error: 1.6583
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6408 - mean_squared_error: 1.6408 - val_loss: 1.3610 - val_mean_squared_error: 1.3610
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4118 - mean_squared_error: 1.4118 - val_loss: 1.1214 - val_mean_squared_error: 1.1214
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2868 - mean_squared_error: 1.2868 - val_loss: 0.8857 - val_mean_squared_error: 0.8857
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9984 - mean_squared_error: 0.9984 - val_loss: 0.6999 - val_mean_squared_error: 0.6999
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7647 - mean_squared_error: 0.7647 - val_loss: 0.5499 - val_mean_squared_error: 0.5499
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6040 - mean_squared_error: 0.6040 - val_loss: 0.4301 - val_mean_squared_error: 0.4301
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5367 - mean_squared_error: 0.5367 - val_loss: 0.3411 - val_mean_squared_error: 0.3411
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4750 - mean_squared_error: 0.4750 - val_loss: 0.2747 - val_mean_squared_error: 0.2747
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3385 - mean_squared_error: 0.3385 - val_loss: 0.2284 - val_mean_squared_error: 0.2284
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3539 - mean_squared_error: 0.3539 - val_loss: 0.1962 - val_mean_squared_error: 0.1962
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3427 - mean_squared_error: 0.3427 - val_loss: 0.1785 - val_mean_squared_error: 0.1785
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2778 - mean_squared_error: 0.2778 - val_loss: 0.1695 - val_mean_squared_error: 0.1695
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2337 - mean_squared_error: 0.2337 - val_loss: 0.1634 - val_mean_squared_error: 0.1634
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1623 - mean_squared_error: 0.1623 - val_loss: 0.1259 - val_mean_squared_error: 0.1259
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1552 - mean_squared_error: 0.1552 - val_loss: 0.1239 - val_mean_squared_error: 0.1239
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1808 - mean_squared_error: 0.1808 - val_loss: 0.1253 - val_mean_squared_error: 0.1253
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1114 - mean_squared_error: 0.1114 - val_loss: 0.1243 - val_mean_squared_error: 0.1243
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2003 - mean_squared_error: 0.2003 - val_loss: 0.1264 - val_mean_squared_error: 0.1264
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1169 - mean_squared_error: 0.1169 - val_loss: 0.1233 - val_mean_squared_error: 0.1233
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1349 - mean_squared_error: 0.1349 - val_loss: 0.1248 - val_mean_squared_error: 0.1248
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1492 - mean_squared_error: 0.1492 - val_loss: 0.1228 - val_mean_squared_error: 0.1228
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1597 - mean_squared_error: 0.1597 - val_loss: 0.1240 - val_mean_squared_error: 0.1240
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1631 - mean_squared_error: 0.1631 - val_loss: 0.1240 - val_mean_squared_error: 0.1240
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1735 - mean_squared_error: 0.1735 - val_loss: 0.1243 - val_mean_squared_error: 0.1243
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1250 - mean_squared_error: 0.1250 - val_loss: 0.1231 - val_mean_squared_error: 0.1231
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1755 - mean_squared_error: 0.1755 - val_loss: 0.1224 - val_mean_squared_error: 0.1224
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1363 - mean_squared_error: 0.1363 - val_loss: 0.1226 - val_mean_squared_error: 0.1226
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²: 0.8746
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 真实值: [7.4506608  5.47227067 3.76120012 5.70211442 6.43775165 4.01638302
#  4.70048037 6.50727771 5.70378247]
# 预测值: [7.324042  5.5638742 3.8404686 5.6936193 6.2837796 4.2481318 4.442227
#  6.462417  5.8409133]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error,accuracy_score

# %%
# 设定自变量与因变量，并划分训练集与测试集
# 首先分析总价
X = data[['对数均价/平方米每元','对数面积','室厅数','是否是车位充足','是否是绿化率高','是否是低总价','是否是低单价']]
Y = data['对数总价']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# 训练模型
models = RandomForestRegressor(n_estimators=50,random_state=42)
models.fit(X_train,Y_train)

# 预测测试集结果
y_pred = models.predict(X_test)

# 计算准确率
mae = mean_absolute_error(Y_test,y_pred)
mse = mean_squared_error(Y_test,y_pred)
r2 = r2_score(Y_test,y_pred)

print('mae:',mae)
print('mse:',mse)
print('r2:',r2)
# Out:
# mae: 0.26327081036541294
# mse: 0.1918052984102585
# r2: 0.762807799596662

# %%
# 设定自变量与因变量，并划分训练集与测试集
# 分析均价
X = data[['对数总价','对数面积','室厅数','是否是品牌房企','是否是人车分流','是否是车位充足','是否是绿化率高','是否是低单价']]
y = data['对数均价/平方米每元']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# 训练模型
models = RandomForestRegressor(n_estimators=50,random_state=42)
models.fit(X_train,Y_train)

# 预测测试集结果
y_pred = models.predict(X_test)

# 计算准确率
mae = mean_absolute_error(Y_test,y_pred)
mse = mean_squared_error(Y_test,y_pred)
r2 = r2_score(Y_test,y_pred)

print('mae:',mae)
print('mse:',mse)
print('r2:',r2)
# Out:
# mae: 0.013742516063327291
# mse: 0.0038240864129790546
# r2: 0.9952710197354042

# %%
models = [model, models]

print(models)
# Out:
# [<Sequential name=sequential, built=True>, RandomForestRegressor(n_estimators=50, random_state=42)]

# %%
print(history)
# Out:
# <keras.src.callbacks.history.History object at 0x315d0c520>
