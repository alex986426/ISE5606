# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from scipy.stats import spearmanr
import statsmodels.api as sm
from statsmodels.formula.api import ols

import warnings
# 忽略所有警告
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.metrics import MeanSquaredError

# %%
filename = '../002Data/preprocessing data.csv'
data = pd.read_csv(filename, encoding='utf-8')
data['室厅数'] = data['室厅数'].str.replace('室', '')

# %%
# 2. 数据预处理
X = data[['对数均价/平方米每元','对数面积','室厅数','是否是车位充足','是否是绿化率高','是否是低总价','是否是低单价']].values
y = data['对数总价'].values
# 特征缩放
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 3. 构建人工神经网络
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)  # 输出层
])

model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])

# 4. 训练模型
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# # 5. 测试模型
# test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
# print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# 5. 评估模型并计算 R²
y_pred = model.predict(X_test).flatten()

# R² 计算
ss_res = np.sum((y_test - y_pred) ** 2)
ss_tot = np.sum((y_test - np.mean(y_test)) ** 2)
r2_score = 1 - (ss_res / ss_tot)

print(f"R²: {r2_score:.4f}")

# 6. 使用模型进行预测
predictions = model.predict(X_test[:9])
print(f"真实值: {y_test[:9]}")
print(f"预测值: {predictions.flatten()}")
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.4026 - mean_squared_error: 30.4026 - val_loss: 26.6296 - val_mean_squared_error: 26.6296
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.8483 - mean_squared_error: 25.8483 - val_loss: 21.2467 - val_mean_squared_error: 21.2467
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7714 - mean_squared_error: 19.7714 - val_loss: 16.0058 - val_mean_squared_error: 16.0058
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7237 - mean_squared_error: 14.7237 - val_loss: 10.7050 - val_mean_squared_error: 10.7050
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4889 - mean_squared_error: 9.4889 - val_loss: 5.9265 - val_mean_squared_error: 5.9265
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4257 - mean_squared_error: 5.4257 - val_loss: 2.7775 - val_mean_squared_error: 2.7775
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4440 - mean_squared_error: 2.4440 - val_loss: 1.7842 - val_mean_squared_error: 1.7842
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7470 - mean_squared_error: 1.7470 - val_loss: 1.5453 - val_mean_squared_error: 1.5453
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3158 - mean_squared_error: 1.3158 - val_loss: 1.2393 - val_mean_squared_error: 1.2393
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0860 - mean_squared_error: 1.0860 - val_loss: 0.9936 - val_mean_squared_error: 0.9936
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9568 - mean_squared_error: 0.9568 - val_loss: 0.8048 - val_mean_squared_error: 0.8048
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7281 - mean_squared_error: 0.7281 - val_loss: 0.6631 - val_mean_squared_error: 0.6631
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6661 - mean_squared_error: 0.6661 - val_loss: 0.5509 - val_mean_squared_error: 0.5509
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5326 - mean_squared_error: 0.5326 - val_loss: 0.4641 - val_mean_squared_error: 0.4641
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3911 - mean_squared_error: 0.3911 - val_loss: 0.3967 - val_mean_squared_error: 0.3967
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3703 - mean_squared_error: 0.3703 - val_loss: 0.3382 - val_mean_squared_error: 0.3382
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3645 - mean_squared_error: 0.3645 - val_loss: 0.2927 - val_mean_squared_error: 0.2927
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2618 - mean_squared_error: 0.2618 - val_loss: 0.2603 - val_mean_squared_error: 0.2603
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2833 - mean_squared_error: 0.2833 - val_loss: 0.2389 - val_mean_squared_error: 0.2389
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2265 - mean_squared_error: 0.2265 - val_loss: 0.2226 - val_mean_squared_error: 0.2226
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1308 - mean_squared_error: 0.1308 - val_loss: 0.1466 - val_mean_squared_error: 0.1466
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1733 - mean_squared_error: 0.1733 - val_loss: 0.1458 - val_mean_squared_error: 0.1458
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1532 - mean_squared_error: 0.1532 - val_loss: 0.1466 - val_mean_squared_error: 0.1466
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1729 - mean_squared_error: 0.1729 - val_loss: 0.1458 - val_mean_squared_error: 0.1458
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1390 - mean_squared_error: 0.1390 - val_loss: 0.1445 - val_mean_squared_error: 0.1445
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1484 - mean_squared_error: 0.1484 - val_loss: 0.1444 - val_mean_squared_error: 0.1444
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1291 - mean_squared_error: 0.1291 - val_loss: 0.1433 - val_mean_squared_error: 0.1433
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1413 - mean_squared_error: 0.1413 - val_loss: 0.1448 - val_mean_squared_error: 0.1448
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1513 - mean_squared_error: 0.1513 - val_loss: 0.1441 - val_mean_squared_error: 0.1441
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1872 - mean_squared_error: 0.1872 - val_loss: 0.1444 - val_mean_squared_error: 0.1444
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1477 - mean_squared_error: 0.1477 - val_loss: 0.1415 - val_mean_squared_error: 0.1415
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1132 - mean_squared_error: 0.1132 - val_loss: 0.1434 - val_mean_squared_error: 0.1434
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1453 - mean_squared_error: 0.1453 - val_loss: 0.1415 - val_mean_squared_error: 0.1415
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1299 - mean_squared_error: 0.1299 - val_loss: 0.1414 - val_mean_squared_error: 0.1414
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1744 - mean_squared_error: 0.1744 - val_loss: 0.1429 - val_mean_squared_error: 0.1429
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x316d360d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²: 0.8654
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 真实值: [7.4506608  5.47227067 3.76120012 5.70211442 6.43775165 4.01638302
#  4.70048037 6.50727771 5.70378247]
# 预测值: [7.3673053 5.5908446 3.9353402 5.6886287 6.3321466 4.394919  4.416814
#  6.475961  5.7857757]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error,accuracy_score

# %%
# 设定自变量与因变量，并划分训练集与测试集
# 首先分析总价
X = data[['对数均价/平方米每元','对数面积','室厅数','是否是车位充足','是否是绿化率高','是否是低总价','是否是低单价']]
Y = data['对数总价']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# 训练模型
models = RandomForestRegressor(n_estimators=50,random_state=42)
models.fit(X_train,Y_train)

# 预测测试集结果
y_pred = models.predict(X_test)

# 计算准确率
mae = mean_absolute_error(Y_test,y_pred)
mse = mean_squared_error(Y_test,y_pred)
r2 = r2_score(Y_test,y_pred)

print('mae:',mae)
print('mse:',mse)
print('r2:',r2)
# Out:
# mae: 0.26327081036541294
# mse: 0.1918052984102585
# r2: 0.762807799596662

# %%
# 设定自变量与因变量，并划分训练集与测试集
# 分析均价
X = data[['对数总价','对数面积','室厅数','是否是品牌房企','是否是人车分流','是否是车位充足','是否是绿化率高','是否是低单价']]
y = data['对数均价/平方米每元']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# 训练模型
models = RandomForestRegressor(n_estimators=50,random_state=42)
models.fit(X_train,Y_train)

# 预测测试集结果
y_pred = models.predict(X_test)

# 计算准确率
mae = mean_absolute_error(Y_test,y_pred)
mse = mean_squared_error(Y_test,y_pred)
r2 = r2_score(Y_test,y_pred)

print('mae:',mae)
print('mse:',mse)
print('r2:',r2)
# Out:
# mae: 0.013742516063327291
# mse: 0.0038240864129790546
# r2: 0.9952710197354042
