# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.metrics import MeanSquaredError
import numpy as np




# 加载数据
# 请将 'your_data.csv' 替换为你实际的数据文件名
data = pd.read_csv('../002Data/preprocessing data.csv')

# 找出所有的分类特征列
categorical_columns = data.select_dtypes(include=['object']).columns

# 对所有分类特征进行独热编码
for col in categorical_columns:
    encoded_col = pd.get_dummies(data[col], prefix=col)
    data = pd.concat([data.drop(col, axis=1), encoded_col], axis=1)

# 定义特征
X = data.drop(['对数总价', '对数均价/平方米每元'], axis=1).values

# 总价目标变量
y_total = data['对数总价'].values
# 均价目标变量
y_avg = data['对数均价/平方米每元'].values

# 特征缩放
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 划分训练集和测试集（总价预测）
X_train_total, X_test_total, y_train_total, y_test_total = train_test_split(
    X_scaled, y_total, test_size=0.2, random_state=42)

# 划分训练集和测试集（均价预测）
X_train_avg, X_test_avg, y_train_avg, y_test_avg = train_test_split(
    X_scaled, y_avg, test_size=0.2, random_state=42)

# 构建人工神经网络
def build_ann_model(input_shape):
    model = Sequential([
        Dense(32, activation='relu', input_shape=(input_shape,)),
        Dense(32, activation='relu'),
        Dense(1)  # 输出层
    ])
    model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])
    return model

# 定义模型评估函数
def evaluate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    return mae, mse, r2

# 人工神经网络模型（总价预测）
ann_total = build_ann_model(X_train_total.shape[1])
history_total = ann_total.fit(X_train_total, y_train_total, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
y_pred_ann_total = ann_total.predict(X_test_total).flatten()
mae_ann_total = mean_absolute_error(y_test_total, y_pred_ann_total)
mse_ann_total = mean_squared_error(y_test_total, y_pred_ann_total)
r2_ann_total = r2_score(y_test_total, y_pred_ann_total)
print("人工神经网络模型（总价预测）:")
print(f"MAE: {mae_ann_total:.4f}, MSE: {mse_ann_total:.4f}, R²: {r2_ann_total:.4f}")

# 人工神经网络模型（均价预测）
ann_avg = build_ann_model(X_train_avg.shape[1])
history_avg = ann_avg.fit(X_train_avg, y_train_avg, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
y_pred_ann_avg = ann_avg.predict(X_test_avg).flatten()
mae_ann_avg = mean_absolute_error(y_test_avg, y_pred_ann_avg)
mse_ann_avg = mean_squared_error(y_test_avg, y_pred_ann_avg)
r2_ann_avg = r2_score(y_test_avg, y_pred_ann_avg)
print("人工神经网络模型（均价预测）:")
print(f"MAE: {mae_ann_avg:.4f}, MSE: {mse_ann_avg:.4f}, R²: {r2_ann_avg:.4f}")

# 随机森林模型（总价预测）
rf_total = RandomForestRegressor(n_estimators=100, random_state=42)
mae_rf_total, mse_rf_total, r2_rf_total = evaluate_model(rf_total, X_train_total, y_train_total, X_test_total, y_test_total)
print("随机森林模型（总价预测）:")
print(f"MAE: {mae_rf_total:.4f}, MSE: {mse_rf_total:.4f}, R²: {r2_rf_total:.4f}")

# 随机森林模型（均价预测）
rf_avg = RandomForestRegressor(n_estimators=100, random_state=42)
mae_rf_avg, mse_rf_avg, r2_rf_avg = evaluate_model(rf_avg, X_train_avg, y_train_avg, X_test_avg, y_test_avg)
print("随机森林模型（均价预测）:")
print(f"MAE: {mae_rf_avg:.4f}, MSE: {mse_rf_avg:.4f}, R²: {r2_rf_avg:.4f}")

# 决策树模型（总价预测）
dt_total = DecisionTreeRegressor(random_state=42)
mae_dt_total, mse_dt_total, r2_dt_total = evaluate_model(dt_total, X_train_total, y_train_total, X_test_total, y_test_total)
print("决策树模型（总价预测）:")
print(f"MAE: {mae_dt_total:.4f}, MSE: {mse_dt_total:.4f}, R²: {r2_dt_total:.4f}")

# 决策树模型（均价预测）
dt_avg = DecisionTreeRegressor(random_state=42)
mae_dt_avg, mse_dt_avg, r2_dt_avg = evaluate_model(dt_avg, X_train_avg, y_train_avg, X_test_avg, y_test_avg)
print("决策树模型（均价预测）:")
print(f"MAE: {mae_dt_avg:.4f}, MSE: {mse_dt_avg:.4f}, R²: {r2_dt_avg:.4f}")


# 梯度提升树模型（总价预测）
gb_total = GradientBoostingRegressor(n_estimators=100, random_state=42)
mae_gb_total, mse_gb_total, r2_gb_total = evaluate_model(gb_total, X_train_total, y_train_total, X_test_total, y_test_total)
print("梯度提升树模型（总价预测）:")
print(f"MAE: {mae_gb_total:.4f}, MSE: {mse_gb_total:.4f}, R²: {r2_gb_total:.4f}")


# 梯度提升树模型（均价预测）
gb_avg = GradientBoostingRegressor(n_estimators=100, random_state=42)
mae_gb_avg, mse_gb_avg, r2_gb_avg = evaluate_model(gb_avg, X_train_avg, y_train_avg, X_test_avg, y_test_avg)
print("梯度提升树模型（均价预测）:")
print(f"MAE: {mae_gb_avg:.4f}, MSE: {mse_gb_avg:.4f}, R²: {r2_gb_avg:.4f}")
# Out:
# Epoch 1/100
# /Users/alexlee/文件/ISE5606/ISE5606/.venv/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.7899 - mean_squared_error: 28.7899 - val_loss: 25.9795 - val_mean_squared_error: 25.9795
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.8105 - mean_squared_error: 24.8105 - val_loss: 19.5969 - val_mean_squared_error: 19.5969
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.6129 - mean_squared_error: 16.6129 - val_loss: 10.0671 - val_mean_squared_error: 10.0671
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5516 - mean_squared_error: 7.5516 - val_loss: 2.1709 - val_mean_squared_error: 2.1709
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2989 - mean_squared_error: 1.2989 - val_loss: 0.8286 - val_mean_squared_error: 0.8286
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8902 - mean_squared_error: 0.8902 - val_loss: 0.6337 - val_mean_squared_error: 0.6337
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5805 - mean_squared_error: 0.5805 - val_loss: 0.6270 - val_mean_squared_error: 0.6270
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4134 - mean_squared_error: 0.4134 - val_loss: 0.5523 - val_mean_squared_error: 0.5523
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3060 - mean_squared_error: 0.3060 - val_loss: 0.4957 - val_mean_squared_error: 0.4957
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3428 - mean_squared_error: 0.3428 - val_loss: 0.4760 - val_mean_squared_error: 0.4760
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2293 - mean_squared_error: 0.2293 - val_loss: 0.4689 - val_mean_squared_error: 0.4689
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2311 - mean_squared_error: 0.2311 - val_loss: 0.4438 - val_mean_squared_error: 0.4438
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2045 - mean_squared_error: 0.2045 - val_loss: 0.4304 - val_mean_squared_error: 0.4304
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1654 - mean_squared_error: 0.1654 - val_loss: 0.4201 - val_mean_squared_error: 0.4201
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1645 - mean_squared_error: 0.1645 - val_loss: 0.4057 - val_mean_squared_error: 0.4057
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.3117 - val_mean_squared_error: 0.3117
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.3119 - val_mean_squared_error: 0.3119
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.3095 - val_mean_squared_error: 0.3095
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.3101 - val_mean_squared_error: 0.3101
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.3088 - val_mean_squared_error: 0.3088
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.3128 - val_mean_squared_error: 0.3128
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.3066 - val_mean_squared_error: 0.3066
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.3129 - val_mean_squared_error: 0.3129
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.3049 - val_mean_squared_error: 0.3049
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.3097 - val_mean_squared_error: 0.3097
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.3036 - val_mean_squared_error: 0.3036
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.3089 - val_mean_squared_error: 0.3089
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0210 - mean_squared_error: 0.0210 - val_loss: 0.3068 - val_mean_squared_error: 0.3068
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.3076 - val_mean_squared_error: 0.3076
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.3098 - val_mean_squared_error: 0.3098
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.3044 - val_mean_squared_error: 0.3044
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.3074 - val_mean_squared_error: 0.3074
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.3079 - val_mean_squared_error: 0.3079
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.3048 - val_mean_squared_error: 0.3048
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.3067 - val_mean_squared_error: 0.3067
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.3058 - val_mean_squared_error: 0.3058
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.3065 - val_mean_squared_error: 0.3065
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.3039 - val_mean_squared_error: 0.3039
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.3033 - val_mean_squared_error: 0.3033
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.3050 - val_mean_squared_error: 0.3050
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.3020 - val_mean_squared_error: 0.3020
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.3045 - val_mean_squared_error: 0.3045
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.3027 - val_mean_squared_error: 0.3027
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.3026 - val_mean_squared_error: 0.3026
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.3001 - val_mean_squared_error: 0.3001
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.3045 - val_mean_squared_error: 0.3045
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.2994 - val_mean_squared_error: 0.2994
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.3036 - val_mean_squared_error: 0.3036
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.2961 - val_mean_squared_error: 0.2961
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.3099 - val_mean_squared_error: 0.3099
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.2995 - val_mean_squared_error: 0.2995
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.3017 - val_mean_squared_error: 0.3017
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.3018 - val_mean_squared_error: 0.3018
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.3036 - val_mean_squared_error: 0.3036
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.2974 - val_mean_squared_error: 0.2974
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.3032 - val_mean_squared_error: 0.3032
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.3025 - val_mean_squared_error: 0.3025
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.2983 - val_mean_squared_error: 0.2983
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.2987 - val_mean_squared_error: 0.2987
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.3023 - val_mean_squared_error: 0.3023
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.2970 - val_mean_squared_error: 0.2970
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.3010 - val_mean_squared_error: 0.3010
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.3056 - val_mean_squared_error: 0.3056
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.2958 - val_mean_squared_error: 0.2958
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.3006 - val_mean_squared_error: 0.3006
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 人工神经网络模型（总价预测）:
# MAE: 0.5190, MSE: 0.4729, R²: 0.4262
# Epoch 1/100
# /Users/alexlee/文件/ISE5606/ISE5606/.venv/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 95.7542 - mean_squared_error: 95.7542 - val_loss: 90.6161 - val_mean_squared_error: 90.6161
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 87.7153 - mean_squared_error: 87.7153 - val_loss: 78.4375 - val_mean_squared_error: 78.4375
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 73.4236 - mean_squared_error: 73.4236 - val_loss: 56.7286 - val_mean_squared_error: 56.7286
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.6915 - mean_squared_error: 48.6915 - val_loss: 28.0088 - val_mean_squared_error: 28.0088
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.9794 - mean_squared_error: 20.9794 - val_loss: 5.5688 - val_mean_squared_error: 5.5688
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.6806 - val_mean_squared_error: 0.6806
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.6842 - val_mean_squared_error: 0.6842
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.6835 - val_mean_squared_error: 0.6835
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.6799 - val_mean_squared_error: 0.6799
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.6765 - val_mean_squared_error: 0.6765
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.6734 - val_mean_squared_error: 0.6734
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.6747 - val_mean_squared_error: 0.6747
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.6756 - val_mean_squared_error: 0.6756
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.6702 - val_mean_squared_error: 0.6702
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.6677 - val_mean_squared_error: 0.6677
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.6721 - val_mean_squared_error: 0.6721
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.6650 - val_mean_squared_error: 0.6650
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.6724 - val_mean_squared_error: 0.6724
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.6598 - val_mean_squared_error: 0.6598
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.6693 - val_mean_squared_error: 0.6693
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.6638 - val_mean_squared_error: 0.6638
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.6582 - val_mean_squared_error: 0.6582
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.6662 - val_mean_squared_error: 0.6662
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.6578 - val_mean_squared_error: 0.6578
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.6583 - val_mean_squared_error: 0.6583
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.6575 - val_mean_squared_error: 0.6575
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.6579 - val_mean_squared_error: 0.6579
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.6553 - val_mean_squared_error: 0.6553
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.6529 - val_mean_squared_error: 0.6529
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.6489 - val_mean_squared_error: 0.6489
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.6547 - val_mean_squared_error: 0.6547
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.6497 - val_mean_squared_error: 0.6497
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.6503 - val_mean_squared_error: 0.6503
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.6512 - val_mean_squared_error: 0.6512
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.6434 - val_mean_squared_error: 0.6434
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.6491 - val_mean_squared_error: 0.6491
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.6499 - val_mean_squared_error: 0.6499
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.6402 - val_mean_squared_error: 0.6402
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.6446 - val_mean_squared_error: 0.6446
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.6444 - val_mean_squared_error: 0.6444
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.6409 - val_mean_squared_error: 0.6409
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.6421 - val_mean_squared_error: 0.6421
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.6412 - val_mean_squared_error: 0.6412
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.6410 - val_mean_squared_error: 0.6410
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.6417 - val_mean_squared_error: 0.6417
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.6345 - val_mean_squared_error: 0.6345
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.6387 - val_mean_squared_error: 0.6387
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.6339 - val_mean_squared_error: 0.6339
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.6410 - val_mean_squared_error: 0.6410
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.6369 - val_mean_squared_error: 0.6369
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.6294 - val_mean_squared_error: 0.6294
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.6418 - val_mean_squared_error: 0.6418
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.6249 - val_mean_squared_error: 0.6249
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.6379 - val_mean_squared_error: 0.6379
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.6323 - val_mean_squared_error: 0.6323
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.6342 - val_mean_squared_error: 0.6342
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.6323 - val_mean_squared_error: 0.6323
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.6288 - val_mean_squared_error: 0.6288
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.6265 - val_mean_squared_error: 0.6265
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.6327 - val_mean_squared_error: 0.6327
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.6288 - val_mean_squared_error: 0.6288
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.6300 - val_mean_squared_error: 0.6300
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.6287 - val_mean_squared_error: 0.6287
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.6288 - val_mean_squared_error: 0.6288
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 人工神经网络模型（均价预测）:
# MAE: 0.5889, MSE: 0.7770, R²: -0.7703
# 随机森林模型（总价预测）:
# MAE: 0.0139, MSE: 0.0024, R²: 0.9971
# 随机森林模型（均价预测）:
# MAE: 0.0045, MSE: 0.0004, R²: 0.9992
# 决策树模型（总价预测）:
# MAE: 0.0281, MSE: 0.0169, R²: 0.9795
# 决策树模型（均价预测）:
# MAE: 0.0038, MSE: 0.0003, R²: 0.9993
# 梯度提升树模型（总价预测）:
# MAE: 0.0123, MSE: 0.0012, R²: 0.9985
# 梯度提升树模型（均价预测）:
# MAE: 0.0028, MSE: 0.0002, R²: 0.9995

# %%
# 定义一个函数来保存评价指标
def save_evaluation_results(model_name, mae, mse, r2, results):
    results.append({
        '模型名': model_name,
        'MAE': mae,
        'MSE': mse,
        'R²': r2
    })

# 初始化一个空列表来存储结果
evaluation_results = []
save_evaluation_results('人工神经网络模型（总价预测）', mae_ann_total, mse_ann_total, r2_ann_total, evaluation_results)
save_evaluation_results('人工神经网络模型（均价预测）', mae_ann_avg, mse_ann_avg, r2_ann_avg, evaluation_results)
save_evaluation_results('随机森林模型（总价预测）', mae_rf_total, mse_rf_total, r2_rf_total, evaluation_results)
save_evaluation_results('随机森林模型（均价预测）', mae_rf_avg, mse_rf_avg, r2_rf_avg, evaluation_results)
save_evaluation_results('决策树模型（总价预测）', mae_dt_total, mse_dt_total, r2_dt_total, evaluation_results)
save_evaluation_results('决策树模型（均价预测）', mae_dt_avg, mse_dt_avg, r2_dt_avg, evaluation_results)
save_evaluation_results('梯度提升树模型（总价预测）', mae_gb_total, mse_gb_total, r2_gb_total, evaluation_results)
save_evaluation_results('梯度提升树模型（均价预测）', mae_gb_avg, mse_gb_avg, r2_gb_avg, evaluation_results)




# 将结果保存到 CSV 文件中
results_df = pd.DataFrame(evaluation_results)
results_df.to_csv('../002Data/EstimatingIndex.csv', index=False, encoding='utf-8-sig')

print("评价指标已保存到 ../002Data/EstimatingIndex.csv 文件中。")
# Out:
# 评价指标已保存到 ../002Data/EstimatingIndex.csv 文件中。

# %%
data = pd.read_csv('../002Data/EstimatingIndex.csv')
print(data)
# Out:
#               模型名       MAE       MSE        R²
# 0  人工神经网络模型（总价预测）  0.519039  0.472896  0.426218
# 1  人工神经网络模型（均价预测）  0.588914  0.776970 -0.770277
# 2    随机森林模型（总价预测）  0.013862  0.002406  0.997081
# 3    随机森林模型（均价预测）  0.004463  0.000373  0.999150
# 4     决策树模型（总价预测）  0.028120  0.016908  0.979485
# 5     决策树模型（均价预测）  0.003802  0.000307  0.999300
# 6   梯度提升树模型（总价预测）  0.012259  0.001202  0.998541
# 7   梯度提升树模型（均价预测）  0.002800  0.000228  0.999479

# %%
# 定义一个函数来保存预测结果
def save_predictions(model_name, true_values, predicted_values, results):
    for true, pred in zip(true_values, predicted_values):
        results.append({
            '模型名称': model_name,
            '真实值': true,
            '预测值': pred
        })

# 初始化一个空列表来存储结果
prediction_results = []




ann_total_predictions = ann_total.predict(X_test_total[:2])
print("人工神经网络模型（总价预测）:")
print(f"真实值: {np.exp(y_test_total[:2])}")
print(f"预测值: {np.exp(ann_total_predictions.flatten())}")
save_predictions('人工神经网络模型（总价预测）', np.exp(y_test_total[:2]), np.exp(ann_total_predictions), prediction_results)
ann_avg_predictions = ann_avg.predict(X_test_avg[:2])
print("人工神经网络模型（均价预测）:")
print(f"真实值: {np.exp(y_test_avg[:2])}")
print(f"预测值: {np.exp(ann_avg_predictions.flatten())}")
save_predictions('人工神经网络模型（均价预测）', np.exp(y_test_avg[:2]), np.exp(ann_avg_predictions), prediction_results)


rf_total_predictions = rf_total.predict(X_test_total[:2])
print("随机森林模型（总价预测）:")
print(f"真实值: {np.exp(y_test_total[:2])}")
print(f"预测值: {np.exp(rf_total_predictions)}")
save_predictions('随机森林模型（总价预测）', np.exp(y_test_total[:2]), np.exp(rf_total_predictions), prediction_results)
rf_avg_predictions = rf_avg.predict(X_test_avg[:2]) 
print("随机森林模型（均价预测）:")
print(f"真实值: {np.exp(y_test_avg[:2])}")
print(f"预测值: {np.exp(rf_avg_predictions)}")
save_predictions('随机森林模型（均价预测）', np.exp(y_test_avg[:2]), np.exp(rf_avg_predictions), prediction_results)


dt_total_predictions = dt_total.predict(X_test_total[:2])
print("决策树模型（总价预测）:")
print(f"真实值: {np.exp(y_test_total[:2])}")
print(f"预测值: {np.exp(dt_total_predictions)}")
save_predictions('决策树模型（总价预测）', np.exp(y_test_total[:2]), np.exp(dt_total_predictions), prediction_results)
dt_avg_predictions = dt_avg.predict(X_test_avg[:2]) 
print("决策树模型（均价预测）:")
print(f"真实值: {np.exp(y_test_avg[:2])}")
print(f"预测值: {np.exp(dt_avg_predictions)}")
save_predictions('决策树模型（均价预测）', np.exp(y_test_avg[:2]), np.exp(dt_avg_predictions), prediction_results)

gb_total_predictions = gb_total.predict(X_test_total[:2])
print("梯度提升树模型（总价预测）:")
print(f"真实值: {np.exp(y_test_total[:2])}")
print(f"预测值: {np.exp(gb_total_predictions)}")
save_predictions('梯度提升树模型（总价预测）', np.exp(y_test_total[:2]), np.exp(gb_total_predictions), prediction_results)
gb_avg_predictions = gb_avg.predict(X_test_avg[:2]) 
print("梯度提升树模型（均价预测）:")
print(f"真实值: {np.exp(y_test_avg[:2])}")
print(f"预测值: {np.exp(gb_avg_predictions)}")
save_predictions('梯度提升树模型（均价预测）', np.exp(y_test_avg[:2]), np.exp(gb_avg_predictions), prediction_results)



# 将结果保存到 CSV 文件中
predictions_df = pd.DataFrame(prediction_results)
predictions_df.to_csv('../002Data/EstimatingPrice.csv', index=False, encoding='utf-8-sig')

print("预测结果已保存到 ../002Data/EstimatingPrice.csv 文件中。")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 人工神经网络模型（总价预测）:
# 真实值: [1721.  238.]
# 预测值: [2686.8374   197.83958]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 人工神经网络模型（均价预测）:
# 真实值: [55000. 23800.]
# 预测值: [109033.766  18804.441]
# 随机森林模型（总价预测）:
# 真实值: [1721.  238.]
# 预测值: [1645.66662034  239.71912837]
# 随机森林模型（均价预测）:
# 真实值: [55000. 23800.]
# 预测值: [55400.5949499 24000.       ]
# 决策树模型（总价预测）:
# 真实值: [1721.  238.]
# 预测值: [1535.   238.5]
# 决策树模型（均价预测）:
# 真实值: [55000. 23800.]
# 预测值: [55000. 24000.]
# 梯度提升树模型（总价预测）:
# 真实值: [1721.  238.]
# 预测值: [1678.08584194  239.6204153 ]
# 梯度提升树模型（均价预测）:
# 真实值: [55000. 23800.]
# 预测值: [55007.54347336 23998.22633106]
# 预测结果已保存到 ../002Data/EstimatingPrice.csv 文件中。
