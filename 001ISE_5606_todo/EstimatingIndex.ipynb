# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.metrics import MeanSquaredError
import numpy as np




# 加载数据
# 请将 'your_data.csv' 替换为你实际的数据文件名
data = pd.read_csv('../002Data/preprocessing data.csv')

# 找出所有的分类特征列
categorical_columns = data.select_dtypes(include=['object']).columns

# 对所有分类特征进行独热编码
for col in categorical_columns:
    encoded_col = pd.get_dummies(data[col], prefix=col)
    data = pd.concat([data.drop(col, axis=1), encoded_col], axis=1)

# 定义特征
X = data.drop(['对数总价', '对数均价/平方米每元'], axis=1).values

# 总价目标变量
y_total = data['对数总价'].values
# 均价目标变量
y_avg = data['对数均价/平方米每元'].values

# 特征缩放
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 划分训练集和测试集（总价预测）
X_train_total, X_test_total, y_train_total, y_test_total = train_test_split(
    X_scaled, y_total, test_size=0.2, random_state=42)

# 划分训练集和测试集（均价预测）
X_train_avg, X_test_avg, y_train_avg, y_test_avg = train_test_split(
    X_scaled, y_avg, test_size=0.2, random_state=42)

# 构建人工神经网络
def build_ann_model(input_shape):
    model = Sequential([
        Dense(32, activation='relu', input_shape=(input_shape,)),
        Dense(32, activation='relu'),
        Dense(1)  # 输出层
    ])
    model.compile(optimizer='adam', loss='mse', metrics=[MeanSquaredError()])
    return model

# 定义模型评估函数
def evaluate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    return mae, mse, r2

# 人工神经网络模型（总价预测）
ann_total = build_ann_model(X_train_total.shape[1])
history_total = ann_total.fit(X_train_total, y_train_total, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
y_pred_ann_total = ann_total.predict(X_test_total).flatten()
mae_ann_total = mean_absolute_error(y_test_total, y_pred_ann_total)
mse_ann_total = mean_squared_error(y_test_total, y_pred_ann_total)
r2_ann_total = r2_score(y_test_total, y_pred_ann_total)
print("人工神经网络模型（总价预测）:")
print(f"MAE: {mae_ann_total:.4f}, MSE: {mse_ann_total:.4f}, R²: {r2_ann_total:.4f}")

# 人工神经网络模型（均价预测）
ann_avg = build_ann_model(X_train_avg.shape[1])
history_avg = ann_avg.fit(X_train_avg, y_train_avg, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
y_pred_ann_avg = ann_avg.predict(X_test_avg).flatten()
mae_ann_avg = mean_absolute_error(y_test_avg, y_pred_ann_avg)
mse_ann_avg = mean_squared_error(y_test_avg, y_pred_ann_avg)
r2_ann_avg = r2_score(y_test_avg, y_pred_ann_avg)
print("人工神经网络模型（均价预测）:")
print(f"MAE: {mae_ann_avg:.4f}, MSE: {mse_ann_avg:.4f}, R²: {r2_ann_avg:.4f}")

# 随机森林模型（总价预测）
rf_total = RandomForestRegressor(n_estimators=100, random_state=42)
mae_rf_total, mse_rf_total, r2_rf_total = evaluate_model(rf_total, X_train_total, y_train_total, X_test_total, y_test_total)
print("随机森林模型（总价预测）:")
print(f"MAE: {mae_rf_total:.4f}, MSE: {mse_rf_total:.4f}, R²: {r2_rf_total:.4f}")

# 随机森林模型（均价预测）
rf_avg = RandomForestRegressor(n_estimators=100, random_state=42)
mae_rf_avg, mse_rf_avg, r2_rf_avg = evaluate_model(rf_avg, X_train_avg, y_train_avg, X_test_avg, y_test_avg)
print("随机森林模型（均价预测）:")
print(f"MAE: {mae_rf_avg:.4f}, MSE: {mse_rf_avg:.4f}, R²: {r2_rf_avg:.4f}")

# 决策树模型（总价预测）
dt_total = DecisionTreeRegressor(random_state=42)
mae_dt_total, mse_dt_total, r2_dt_total = evaluate_model(dt_total, X_train_total, y_train_total, X_test_total, y_test_total)
print("决策树模型（总价预测）:")
print(f"MAE: {mae_dt_total:.4f}, MSE: {mse_dt_total:.4f}, R²: {r2_dt_total:.4f}")

# 决策树模型（均价预测）
dt_avg = DecisionTreeRegressor(random_state=42)
mae_dt_avg, mse_dt_avg, r2_dt_avg = evaluate_model(dt_avg, X_train_avg, y_train_avg, X_test_avg, y_test_avg)
print("决策树模型（均价预测）:")
print(f"MAE: {mae_dt_avg:.4f}, MSE: {mse_dt_avg:.4f}, R²: {r2_dt_avg:.4f}")


# 梯度提升树模型（总价预测）
gb_total = GradientBoostingRegressor(n_estimators=100, random_state=42)
mae_gb_total, mse_gb_total, r2_gb_total = evaluate_model(gb_total, X_train_total, y_train_total, X_test_total, y_test_total)
print("梯度提升树模型（总价预测）:")
print(f"MAE: {mae_gb_total:.4f}, MSE: {mse_gb_total:.4f}, R²: {r2_gb_total:.4f}")


# 梯度提升树模型（均价预测）
gb_avg = GradientBoostingRegressor(n_estimators=100, random_state=42)
mae_gb_avg, mse_gb_avg, r2_gb_avg = evaluate_model(gb_avg, X_train_avg, y_train_avg, X_test_avg, y_test_avg)
print("梯度提升树模型（均价预测）:")
print(f"MAE: {mae_gb_avg:.4f}, MSE: {mse_gb_avg:.4f}, R²: {r2_gb_avg:.4f}")
# Out:
# /Users/alexlee/文件/ISE5606/ISE5606/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Epoch 1/100
# /Users/alexlee/文件/ISE5606/ISE5606/.venv/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.3989 - mean_squared_error: 28.3989 - val_loss: 26.4216 - val_mean_squared_error: 26.4216
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.9623 - mean_squared_error: 24.9623 - val_loss: 20.9133 - val_mean_squared_error: 20.9133
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.1894 - mean_squared_error: 18.1894 - val_loss: 12.1229 - val_mean_squared_error: 12.1229
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6165 - mean_squared_error: 8.6165 - val_loss: 3.1014 - val_mean_squared_error: 3.1014
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7644 - mean_squared_error: 1.7644 - val_loss: 0.7092 - val_mean_squared_error: 0.7092
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8748 - mean_squared_error: 0.8748 - val_loss: 0.6461 - val_mean_squared_error: 0.6461
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6178 - mean_squared_error: 0.6178 - val_loss: 0.6596 - val_mean_squared_error: 0.6596
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5018 - mean_squared_error: 0.5018 - val_loss: 0.5961 - val_mean_squared_error: 0.5961
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4121 - mean_squared_error: 0.4121 - val_loss: 0.5386 - val_mean_squared_error: 0.5386
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3375 - mean_squared_error: 0.3375 - val_loss: 0.5310 - val_mean_squared_error: 0.5310
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3256 - mean_squared_error: 0.3256 - val_loss: 0.5023 - val_mean_squared_error: 0.5023
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2602 - mean_squared_error: 0.2602 - val_loss: 0.4935 - val_mean_squared_error: 0.4935
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.4749 - val_mean_squared_error: 0.4749
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1980 - mean_squared_error: 0.1980 - val_loss: 0.4633 - val_mean_squared_error: 0.4633
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1964 - mean_squared_error: 0.1964 - val_loss: 0.4510 - val_mean_squared_error: 0.4510
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1731 - mean_squared_error: 0.1731 - val_loss: 0.4414 - val_mean_squared_error: 0.4414
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1266 - mean_squared_error: 0.1266 - val_loss: 0.4312 - val_mean_squared_error: 0.4312
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1255 - mean_squared_error: 0.1255 - val_loss: 0.4212 - val_mean_squared_error: 0.4212
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1085 - mean_squared_error: 0.1085 - val_loss: 0.4115 - val_mean_squared_error: 0.4115
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1145 - mean_squared_error: 0.1145 - val_loss: 0.4081 - val_mean_squared_error: 0.4081
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1104 - mean_squared_error: 0.1104 - val_loss: 0.3994 - val_mean_squared_error: 0.3994
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1100 - mean_squared_error: 0.1100 - val_loss: 0.3929 - val_mean_squared_error: 0.3929
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0820 - mean_squared_error: 0.0820 - val_loss: 0.3900 - val_mean_squared_error: 0.3900
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0646 - mean_squared_error: 0.0646 - val_loss: 0.3823 - val_mean_squared_error: 0.3823
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0627 - mean_squared_error: 0.0627 - val_loss: 0.3804 - val_mean_squared_error: 0.3804
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0553 - mean_squared_error: 0.0553 - val_loss: 0.3745 - val_mean_squared_error: 0.3745
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0550 - mean_squared_error: 0.0550 - val_loss: 0.3726 - val_mean_squared_error: 0.3726
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - mean_squared_error: 0.0457 - val_loss: 0.3662 - val_mean_squared_error: 0.3662
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.3664 - val_mean_squared_error: 0.3664
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0464 - mean_squared_error: 0.0464 - val_loss: 0.3610 - val_mean_squared_error: 0.3610
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0400 - mean_squared_error: 0.0400 - val_loss: 0.3611 - val_mean_squared_error: 0.3611
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0433 - mean_squared_error: 0.0433 - val_loss: 0.3547 - val_mean_squared_error: 0.3547
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0461 - mean_squared_error: 0.0461 - val_loss: 0.3546 - val_mean_squared_error: 0.3546
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.3518 - val_mean_squared_error: 0.3518
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.3493 - val_mean_squared_error: 0.3493
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0332 - mean_squared_error: 0.0332 - val_loss: 0.3505 - val_mean_squared_error: 0.3505
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.3492 - val_mean_squared_error: 0.3492
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.3448 - val_mean_squared_error: 0.3448
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.3478 - val_mean_squared_error: 0.3478
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - val_loss: 0.3456 - val_mean_squared_error: 0.3456
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.3435 - val_mean_squared_error: 0.3435
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.3440 - val_mean_squared_error: 0.3440
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.3423 - val_mean_squared_error: 0.3423
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.3442 - val_mean_squared_error: 0.3442
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.3392 - val_mean_squared_error: 0.3392
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.3412 - val_mean_squared_error: 0.3412
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.3385 - val_mean_squared_error: 0.3385
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.3419 - val_mean_squared_error: 0.3419
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.3381 - val_mean_squared_error: 0.3381
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.3378 - val_mean_squared_error: 0.3378
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.3359 - val_mean_squared_error: 0.3359
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.3342 - val_mean_squared_error: 0.3342
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.3352 - val_mean_squared_error: 0.3352
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.3330 - val_mean_squared_error: 0.3330
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.3343 - val_mean_squared_error: 0.3343
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.3335 - val_mean_squared_error: 0.3335
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.3331 - val_mean_squared_error: 0.3331
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.3317 - val_mean_squared_error: 0.3317
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.3337 - val_mean_squared_error: 0.3337
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.3292 - val_mean_squared_error: 0.3292
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.3322 - val_mean_squared_error: 0.3322
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.3287 - val_mean_squared_error: 0.3287
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.3319 - val_mean_squared_error: 0.3319
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.3278 - val_mean_squared_error: 0.3278
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.3312 - val_mean_squared_error: 0.3312
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.3262 - val_mean_squared_error: 0.3262
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.3290 - val_mean_squared_error: 0.3290
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.3262 - val_mean_squared_error: 0.3262
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.3241 - val_mean_squared_error: 0.3241
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.3275 - val_mean_squared_error: 0.3275
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.3243 - val_mean_squared_error: 0.3243
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.3258 - val_mean_squared_error: 0.3258
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.3232 - val_mean_squared_error: 0.3232
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.3233 - val_mean_squared_error: 0.3233
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.3204 - val_mean_squared_error: 0.3204
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.3267 - val_mean_squared_error: 0.3267
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.3184 - val_mean_squared_error: 0.3184
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.3233 - val_mean_squared_error: 0.3233
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.3206 - val_mean_squared_error: 0.3206
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.3225 - val_mean_squared_error: 0.3225
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.3178 - val_mean_squared_error: 0.3178
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.3199 - val_mean_squared_error: 0.3199
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.3194 - val_mean_squared_error: 0.3194
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.3167 - val_mean_squared_error: 0.3167
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.3168 - val_mean_squared_error: 0.3168
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.3166 - val_mean_squared_error: 0.3166
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.3151 - val_mean_squared_error: 0.3151
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.3152 - val_mean_squared_error: 0.3152
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.3186 - val_mean_squared_error: 0.3186
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.3175 - val_mean_squared_error: 0.3175
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.3131 - val_mean_squared_error: 0.3131
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.3216 - val_mean_squared_error: 0.3216
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.3105 - val_mean_squared_error: 0.3105
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.3166 - val_mean_squared_error: 0.3166
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.3142 - val_mean_squared_error: 0.3142
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.3095 - val_mean_squared_error: 0.3095
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.3181 - val_mean_squared_error: 0.3181
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.3168 - val_mean_squared_error: 0.3168
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.3120 - val_mean_squared_error: 0.3120
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.3102 - val_mean_squared_error: 0.3102
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 人工神经网络模型（总价预测）:
# MAE: 0.5015, MSE: 0.4585, R²: 0.4437
# Epoch 1/100
# /Users/alexlee/文件/ISE5606/ISE5606/.venv/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 96.6519 - mean_squared_error: 96.6519 - val_loss: 92.1622 - val_mean_squared_error: 92.1622
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.7688 - mean_squared_error: 89.7688 - val_loss: 82.6981 - val_mean_squared_error: 82.6981
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 79.4635 - mean_squared_error: 79.4635 - val_loss: 66.9329 - val_mean_squared_error: 66.9329
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 60.8297 - mean_squared_error: 60.8297 - val_loss: 44.1046 - val_mean_squared_error: 44.1046
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.5055 - mean_squared_error: 37.5055 - val_loss: 19.0827 - val_mean_squared_error: 19.0827
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.5177 - mean_squared_error: 13.5177 - val_loss: 3.3697 - val_mean_squared_error: 3.3697
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3787 - mean_squared_error: 2.3787 - val_loss: 1.3631 - val_mean_squared_error: 1.3631
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7350 - mean_squared_error: 1.7350 - val_loss: 1.1666 - val_mean_squared_error: 1.1666
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1377 - mean_squared_error: 1.1377 - val_loss: 1.1514 - val_mean_squared_error: 1.1514
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0366 - mean_squared_error: 1.0366 - val_loss: 1.1063 - val_mean_squared_error: 1.1063
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7949 - mean_squared_error: 0.7949 - val_loss: 1.0145 - val_mean_squared_error: 1.0145
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7408 - mean_squared_error: 0.7408 - val_loss: 0.9771 - val_mean_squared_error: 0.9771
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6466 - mean_squared_error: 0.6466 - val_loss: 0.9584 - val_mean_squared_error: 0.9584
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4959 - mean_squared_error: 0.4959 - val_loss: 0.9322 - val_mean_squared_error: 0.9322
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4503 - mean_squared_error: 0.4503 - val_loss: 0.8988 - val_mean_squared_error: 0.8988
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4143 - mean_squared_error: 0.4143 - val_loss: 0.8804 - val_mean_squared_error: 0.8804
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3490 - mean_squared_error: 0.3490 - val_loss: 0.8608 - val_mean_squared_error: 0.8608
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2993 - mean_squared_error: 0.2993 - val_loss: 0.8382 - val_mean_squared_error: 0.8382
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2446 - mean_squared_error: 0.2446 - val_loss: 0.8229 - val_mean_squared_error: 0.8229
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1959 - mean_squared_error: 0.1959 - val_loss: 0.8078 - val_mean_squared_error: 0.8078
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1644 - mean_squared_error: 0.1644 - val_loss: 0.7932 - val_mean_squared_error: 0.7932
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1563 - mean_squared_error: 0.1563 - val_loss: 0.7859 - val_mean_squared_error: 0.7859
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1664 - mean_squared_error: 0.1664 - val_loss: 0.7649 - val_mean_squared_error: 0.7649
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1283 - mean_squared_error: 0.1283 - val_loss: 0.7621 - val_mean_squared_error: 0.7621
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1128 - mean_squared_error: 0.1128 - val_loss: 0.7445 - val_mean_squared_error: 0.7445
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0915 - mean_squared_error: 0.0915 - val_loss: 0.7349 - val_mean_squared_error: 0.7349
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0706 - mean_squared_error: 0.0706 - val_loss: 0.7243 - val_mean_squared_error: 0.7243
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0671 - mean_squared_error: 0.0671 - val_loss: 0.7162 - val_mean_squared_error: 0.7162
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mean_squared_error: 0.0512 - val_loss: 0.7060 - val_mean_squared_error: 0.7060
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0497 - mean_squared_error: 0.0497 - val_loss: 0.7040 - val_mean_squared_error: 0.7040
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.6960 - val_mean_squared_error: 0.6960
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.6930 - val_mean_squared_error: 0.6930
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.6862 - val_mean_squared_error: 0.6862
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.6832 - val_mean_squared_error: 0.6832
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0274 - mean_squared_error: 0.0274 - val_loss: 0.6802 - val_mean_squared_error: 0.6802
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.6772 - val_mean_squared_error: 0.6772
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.6686 - val_mean_squared_error: 0.6686
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.6687 - val_mean_squared_error: 0.6687
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.6615 - val_mean_squared_error: 0.6615
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.6628 - val_mean_squared_error: 0.6628
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.6553 - val_mean_squared_error: 0.6553
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.6555 - val_mean_squared_error: 0.6555
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.6499 - val_mean_squared_error: 0.6499
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.6517 - val_mean_squared_error: 0.6517
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.6476 - val_mean_squared_error: 0.6476
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.6467 - val_mean_squared_error: 0.6467
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.6445 - val_mean_squared_error: 0.6445
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.6416 - val_mean_squared_error: 0.6416
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.6392 - val_mean_squared_error: 0.6392
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.6408 - val_mean_squared_error: 0.6408
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.6338 - val_mean_squared_error: 0.6338
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.6415 - val_mean_squared_error: 0.6415
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.6309 - val_mean_squared_error: 0.6309
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.6345 - val_mean_squared_error: 0.6345
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.6312 - val_mean_squared_error: 0.6312
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.6326 - val_mean_squared_error: 0.6326
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.6304 - val_mean_squared_error: 0.6304
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.6257 - val_mean_squared_error: 0.6257
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.6264 - val_mean_squared_error: 0.6264
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.6253 - val_mean_squared_error: 0.6253
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.6276 - val_mean_squared_error: 0.6276
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.6233 - val_mean_squared_error: 0.6233
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.6243 - val_mean_squared_error: 0.6243
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.6206 - val_mean_squared_error: 0.6206
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.6239 - val_mean_squared_error: 0.6239
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.6210 - val_mean_squared_error: 0.6210
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.6195 - val_mean_squared_error: 0.6195
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.6183 - val_mean_squared_error: 0.6183
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.6210 - val_mean_squared_error: 0.6210
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.6174 - val_mean_squared_error: 0.6174
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.6156 - val_mean_squared_error: 0.6156
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.6184 - val_mean_squared_error: 0.6184
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.6133 - val_mean_squared_error: 0.6133
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.6199 - val_mean_squared_error: 0.6199
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.6153 - val_mean_squared_error: 0.6153
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.6120 - val_mean_squared_error: 0.6120
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.6186 - val_mean_squared_error: 0.6186
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.6091 - val_mean_squared_error: 0.6091
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.6128 - val_mean_squared_error: 0.6128
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.6116 - val_mean_squared_error: 0.6116
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.6067 - val_mean_squared_error: 0.6067
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.6125 - val_mean_squared_error: 0.6125
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.6085 - val_mean_squared_error: 0.6085
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.6097 - val_mean_squared_error: 0.6097
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.6047 - val_mean_squared_error: 0.6047
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.6059 - val_mean_squared_error: 0.6059
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.6094 - val_mean_squared_error: 0.6094
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.6033 - val_mean_squared_error: 0.6033
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.6091 - val_mean_squared_error: 0.6091
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.6036 - val_mean_squared_error: 0.6036
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.6019 - val_mean_squared_error: 0.6019
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.6039 - val_mean_squared_error: 0.6039
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.6002 - val_mean_squared_error: 0.6002
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.6055 - val_mean_squared_error: 0.6055
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.6031 - val_mean_squared_error: 0.6031
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.6016 - val_mean_squared_error: 0.6016
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.6018 - val_mean_squared_error: 0.6018
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.5985 - val_mean_squared_error: 0.5985
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.6013 - val_mean_squared_error: 0.6013
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.5988 - val_mean_squared_error: 0.5988
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 人工神经网络模型（均价预测）:
# MAE: 0.5925, MSE: 0.6950, R²: -0.5835
# 随机森林模型（总价预测）:
# MAE: 0.0139, MSE: 0.0024, R²: 0.9971
# 随机森林模型（均价预测）:
# MAE: 0.0045, MSE: 0.0004, R²: 0.9992
# 决策树模型（总价预测）:
# MAE: 0.0281, MSE: 0.0169, R²: 0.9795
# 决策树模型（均价预测）:
# MAE: 0.0038, MSE: 0.0003, R²: 0.9993
# 梯度提升树模型（总价预测）:
# MAE: 0.0123, MSE: 0.0012, R²: 0.9985
# 梯度提升树模型（均价预测）:
# MAE: 0.0028, MSE: 0.0002, R²: 0.9995

# %%
# 定义一个函数来保存评价指标
def save_evaluation_results(model_name, mae, mse, r2, results):
    results.append({
        '模型名': model_name,
        'MAE': mae,
        'MSE': mse,
        'R²': r2
    })

# 初始化一个空列表来存储结果
evaluation_results = []
save_evaluation_results('人工神经网络模型（总价预测）', mae_ann_total, mse_ann_total, r2_ann_total, evaluation_results)
save_evaluation_results('人工神经网络模型（均价预测）', mae_ann_avg, mse_ann_avg, r2_ann_avg, evaluation_results)
save_evaluation_results('随机森林模型（总价预测）', mae_rf_total, mse_rf_total, r2_rf_total, evaluation_results)
save_evaluation_results('随机森林模型（均价预测）', mae_rf_avg, mse_rf_avg, r2_rf_avg, evaluation_results)
save_evaluation_results('决策树模型（总价预测）', mae_dt_total, mse_dt_total, r2_dt_total, evaluation_results)
save_evaluation_results('决策树模型（均价预测）', mae_dt_avg, mse_dt_avg, r2_dt_avg, evaluation_results)
save_evaluation_results('梯度提升树模型（总价预测）', mae_gb_total, mse_gb_total, r2_gb_total, evaluation_results)
save_evaluation_results('梯度提升树模型（均价预测）', mae_gb_avg, mse_gb_avg, r2_gb_avg, evaluation_results)




# 将结果保存到 CSV 文件中
results_df = pd.DataFrame(evaluation_results)
results_df.to_csv('../002Data/EstimatingIndex.csv', index=False, encoding='utf-8-sig')

print("评价指标已保存到 ../002Data/EstimatingIndex.csv 文件中。")
# Out:
# 评价指标已保存到 ../002Data/EstimatingIndex.csv 文件中。

# %%
data = pd.read_csv('../002Data/EstimatingIndex.csv')
print(data)
# Out:
#               模型名       MAE       MSE        R²
# 0  人工神经网络模型（总价预测）  0.501535  0.458524  0.443657
# 1  人工神经网络模型（均价预测）  0.592525  0.694979 -0.583466
# 2    随机森林模型（总价预测）  0.013862  0.002406  0.997081
# 3    随机森林模型（均价预测）  0.004463  0.000373  0.999150
# 4     决策树模型（总价预测）  0.028120  0.016908  0.979485
# 5     决策树模型（均价预测）  0.003802  0.000307  0.999300
# 6   梯度提升树模型（总价预测）  0.012259  0.001202  0.998541
# 7   梯度提升树模型（均价预测）  0.002800  0.000228  0.999479

# %%
# 定义一个函数来保存预测结果
def save_predictions(model_name, true_values, predicted_values, results):
    for true, pred in zip(true_values, predicted_values):
        results.append({
            '模型名称': model_name,
            '真实值': true,
            '预测值': pred
        })

# 初始化一个空列表来存储结果
prediction_results = []




ann_total_predictions = ann_total.predict(X_test_total[:2])
print("人工神经网络模型（总价预测）:")
print(f"真实值: {np.exp(y_test_total[:2])}")
print(f"预测值: {np.exp(ann_total_predictions.flatten())}")
save_predictions('人工神经网络模型（总价预测）', np.exp(y_test_total[:2]), np.exp(ann_total_predictions), prediction_results)
ann_avg_predictions = ann_avg.predict(X_test_avg[:2])
print("人工神经网络模型（均价预测）:")
print(f"真实值: {np.exp(y_test_avg[:2])}")
print(f"预测值: {np.exp(ann_avg_predictions.flatten())}")
save_predictions('人工神经网络模型（均价预测）', np.exp(y_test_avg[:2]), np.exp(ann_avg_predictions), prediction_results)


rf_total_predictions = rf_total.predict(X_test_total[:2])
print("随机森林模型（总价预测）:")
print(f"真实值: {np.exp(y_test_total[:2])}")
print(f"预测值: {np.exp(rf_total_predictions)}")
save_predictions('随机森林模型（总价预测）', np.exp(y_test_total[:2]), np.exp(rf_total_predictions), prediction_results)
rf_avg_predictions = rf_avg.predict(X_test_avg[:2]) 
print("随机森林模型（均价预测）:")
print(f"真实值: {np.exp(y_test_avg[:2])}")
print(f"预测值: {np.exp(rf_avg_predictions)}")
save_predictions('随机森林模型（均价预测）', np.exp(y_test_avg[:2]), np.exp(rf_avg_predictions), prediction_results)


dt_total_predictions = dt_total.predict(X_test_total[:2])
print("决策树模型（总价预测）:")
print(f"真实值: {np.exp(y_test_total[:2])}")
print(f"预测值: {np.exp(dt_total_predictions)}")
save_predictions('决策树模型（总价预测）', np.exp(y_test_total[:2]), np.exp(dt_total_predictions), prediction_results)
dt_avg_predictions = dt_avg.predict(X_test_avg[:2]) 
print("决策树模型（均价预测）:")
print(f"真实值: {np.exp(y_test_avg[:2])}")
print(f"预测值: {np.exp(dt_avg_predictions)}")
save_predictions('决策树模型（均价预测）', np.exp(y_test_avg[:2]), np.exp(dt_avg_predictions), prediction_results)

gb_total_predictions = gb_total.predict(X_test_total[:2])
print("梯度提升树模型（总价预测）:")
print(f"真实值: {np.exp(y_test_total[:2])}")
print(f"预测值: {np.exp(gb_total_predictions)}")
save_predictions('梯度提升树模型（总价预测）', np.exp(y_test_total[:2]), np.exp(gb_total_predictions), prediction_results)
gb_avg_predictions = gb_avg.predict(X_test_avg[:2]) 
print("梯度提升树模型（均价预测）:")
print(f"真实值: {np.exp(y_test_avg[:2])}")
print(f"预测值: {np.exp(gb_avg_predictions)}")
save_predictions('梯度提升树模型（均价预测）', np.exp(y_test_avg[:2]), np.exp(gb_avg_predictions), prediction_results)



# 将结果保存到 CSV 文件中
predictions_df = pd.DataFrame(prediction_results)
predictions_df.to_csv('../002Data/EstimatingPrice.csv', index=False, encoding='utf-8-sig')

print("预测结果已保存到 ../002Data/EstimatingPrice.csv 文件中。")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 人工神经网络模型（总价预测）:
# 真实值: [1721.  238.]
# 预测值: [2507.5183   161.73134]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 人工神经网络模型（均价预测）:
# 真实值: [55000. 23800.]
# 预测值: [68774.67  10383.897]
# 随机森林模型（总价预测）:
# 真实值: [1721.  238.]
# 预测值: [1645.66662034  239.71912837]
# 随机森林模型（均价预测）:
# 真实值: [55000. 23800.]
# 预测值: [55400.5949499 24000.       ]
# 决策树模型（总价预测）:
# 真实值: [1721.  238.]
# 预测值: [1535.   238.5]
# 决策树模型（均价预测）:
# 真实值: [55000. 23800.]
# 预测值: [55000. 24000.]
# 梯度提升树模型（总价预测）:
# 真实值: [1721.  238.]
# 预测值: [1678.08584194  239.6204153 ]
# 梯度提升树模型（均价预测）:
# 真实值: [55000. 23800.]
# 预测值: [55007.54347336 23998.22633106]
# 预测结果已保存到 ../002Data/EstimatingPrice.csv 文件中。
